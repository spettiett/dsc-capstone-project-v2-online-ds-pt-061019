# %% [markdown]
# ##  Part II: Hypothesis Testing | Jupyter Notebook

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * __Student name:__        Sharonda Warner
# * __Student pace:__        PT 061019
# * __Project review date:__ 24 Apr 2020
# * __Instructor name:__     Eli Thomas

# %% [markdown]
# # Begin Study
# > In this notebook I will conduct hypothesis testing to determine the following:
#   - __Question 1:__ Booking far in advance increases the probability of cancellation?
#   - __Question 2:__ If true, then which lead time days significantly effect those cancellations?

# %%
import datetime
start = datetime.datetime.now()

# %% [markdown]
# ## Load Libraries

# %%
# Load Libraries

import os
import math
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import flatiron_stats as fs

# %matplotlib inline
plt.style.use("ggplot")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load and Preview Data

# %%
# Load Data
dataset = pd.read_csv('./hotel_bookings.csv')
print(dataset.shape)
dataset.head()
# Out:
# (119390, 32)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# 1                        0                     0       2       0.0       0
# 2                        0                     1       1       0.0       0
# 3                        0                     1       1       0.0       0
# 4                        0                     2       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     PRT         Direct               Direct                  0
# 1   BB     PRT         Direct               Direct                  0
# 2   BB     GBR         Direct               Direct                  0
# 3   BB     GBR      Corporate            Corporate                  0
# 4   BB     GBR      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  company  \
# 0                  C                3   No Deposit    NaN      NaN
# 1                  C                4   No Deposit    NaN      NaN
# 2                  C                0   No Deposit    NaN      NaN
# 3                  A                0   No Deposit  304.0      NaN
# 4                  A                0   No Deposit  240.0      NaN
#
#    days_in_waiting_list customer_type   adr  required_car_parking_spaces  \
# 0                     0     Transient   0.0                            0
# 1                     0     Transient   0.0                            0
# 2                     0     Transient  75.0                            0
# 3                     0     Transient  75.0                            0
# 4                     0     Transient  98.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03

# %% [markdown]
# # __Hypothesis Test 1:Does the Lead Time have an effect on cancellations?__

# %% [markdown]
# ## State Hypothesis:
# - $H_{0}$: The null hypothesis is that lead time does __not__ have an effect on cancellations.
#
#   $H_{0}: \mu1 = \mu2$
#
#
# - $H_{1}$: The alternative hypothesis is that lead time __does__ have an effect on cancellations.
#
#   $H_{1}: \mu1 ≠ \mu2$
#
#
# - __α__:   The significance level, also denoted as alpha or α, is the probability of rejecting the null hypothesis when it is true.
#
#   __α__ = 0.05 or 5%

# %%
# The significance level, also denoted as alpha or α, is the probability of rejecting the null hypothesis when it is true.
alpha = 0.05

# %% [markdown]
# ## EDA

# %%
# For each column review data types and # of rows.
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
# hotel                             119390 non-null object
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null object
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119386 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null object
# country                           118902 non-null object
# market_segment                    119390 non-null object
# distribution_channel              119390 non-null object
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# reserved_room_type                119390 non-null object
# assigned_room_type                119390 non-null object
# booking_changes                   119390 non-null int64
# deposit_type                      119390 non-null object
# agent                             103050 non-null float64
# company                           6797 non-null float64
# days_in_waiting_list              119390 non-null int64
# customer_type                     119390 non-null object
# adr                               119390 non-null float64
# required_car_parking_spaces       119390 non-null int64
# total_of_special_requests         119390 non-null int64
# reservation_status                119390 non-null object
# reservation_status_date           119390 non-null object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
# Check for null values in the data
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
# View Statistics for booked 
dataset[dataset['is_canceled']==0].describe(include='all')
# Out:
#              hotel  is_canceled     lead_time  arrival_date_year  \
# count        75166      75166.0  75166.000000       75166.000000
# unique           2          NaN           NaN                NaN
# top     City Hotel          NaN           NaN                NaN
# freq         46228          NaN           NaN                NaN
# mean           NaN          0.0     79.984687        2016.147514
# std            NaN          0.0     91.109888           0.703124
# min            NaN          0.0      0.000000        2015.000000
# 25%            NaN          0.0      9.000000        2016.000000
# 50%            NaN          0.0     45.000000        2016.000000
# 75%            NaN          0.0    124.000000        2017.000000
# max            NaN          0.0    737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               75166              75166.000000
# unique                 12                       NaN
# top                August                       NaN
# freq                 8638                       NaN
# mean                  NaN                 27.080143
# std                   NaN                 13.902478
# min                   NaN                  1.000000
# 25%                   NaN                 16.000000
# 50%                   NaN                 28.000000
# 75%                   NaN                 38.000000
# max                   NaN                 53.000000
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# count                75166.000000             75166.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                    15.839529                 0.928971
# std                      8.776422                 0.993371
# min                      1.000000                 0.000000
# 25%                      8.000000                 0.000000
# 50%                     16.000000                 1.000000
# 75%                     23.000000                 2.000000
# max                     31.000000                19.000000
#
#         stays_in_week_nights        adults      children        babies   meal  \
# count           75166.000000  75166.000000  75166.000000  75166.000000  75166
# unique                   NaN           NaN           NaN           NaN      5
# top                      NaN           NaN           NaN           NaN     BB
# freq                     NaN           NaN           NaN           NaN  57800
# mean                2.464053      1.829737      0.102347      0.010377    NaN
# std                 1.924803      0.510451      0.390836      0.113007    NaN
# min                 0.000000      0.000000      0.000000      0.000000    NaN
# 25%                 1.000000      2.000000      0.000000      0.000000    NaN
# 50%                 2.000000      2.000000      0.000000      0.000000    NaN
# 75%                 3.000000      2.000000      0.000000      0.000000    NaN
# max                50.000000      4.000000      3.000000     10.000000    NaN
#
#        country market_segment distribution_channel  is_repeated_guest  \
# count    74745          75166                75166       75166.000000
# unique     165              7                    5                NaN
# top        PRT      Online TA                TA/TO                NaN
# freq     21071          35738                57718                NaN
# mean       NaN            NaN                  NaN           0.043344
# std        NaN            NaN                  NaN           0.203632
# min        NaN            NaN                  NaN           0.000000
# 25%        NaN            NaN                  NaN           0.000000
# 50%        NaN            NaN                  NaN           0.000000
# 75%        NaN            NaN                  NaN           0.000000
# max        NaN            NaN                  NaN           1.000000
#
#         previous_cancellations  previous_bookings_not_canceled  \
# count             75166.000000                    75166.000000
# unique                     NaN                             NaN
# top                        NaN                             NaN
# freq                       NaN                             NaN
# mean                  0.015792                        0.202977
# std                   0.272421                        1.810713
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                  13.000000                       72.000000
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# count               75166              75166     75166.000000        75166
# unique                  9                 10              NaN            3
# top                     A                  A              NaN   No Deposit
# freq                52364              41105              NaN        74947
# mean                  NaN                NaN         0.293364          NaN
# std                   NaN                NaN         0.736266          NaN
# min                   NaN                NaN         0.000000          NaN
# 25%                   NaN                NaN         0.000000          NaN
# 50%                   NaN                NaN         0.000000          NaN
# 75%                   NaN                NaN         0.000000          NaN
# max                   NaN                NaN        21.000000          NaN
#
#                agent      company  days_in_waiting_list customer_type  \
# count   62856.000000  5606.000000          75166.000000         75166
# unique           NaN          NaN                   NaN             4
# top              NaN          NaN                   NaN     Transient
# freq             NaN          NaN                   NaN         53099
# mean       94.055794   190.519265              1.589868           NaN
# std       113.947162   132.349286             14.784875           NaN
# min         1.000000     6.000000              0.000000           NaN
# 25%         9.000000    51.000000              0.000000           NaN
# 50%        14.000000   183.000000              0.000000           NaN
# 75%       240.000000   270.000000              0.000000           NaN
# max       535.000000   541.000000            379.000000           NaN
#
#                  adr  required_car_parking_spaces  total_of_special_requests  \
# count   75166.000000                 75166.000000               75166.000000
# unique           NaN                          NaN                        NaN
# top              NaN                          NaN                        NaN
# freq             NaN                          NaN                        NaN
# mean       99.987693                     0.099300                   0.714060
# std        49.206263                     0.303176                   0.833887
# min        -6.380000                     0.000000                   0.000000
# 25%        67.500000                     0.000000                   0.000000
# 50%        92.500000                     0.000000                   1.000000
# 75%       125.000000                     0.000000                   1.000000
# max       510.000000                     8.000000                   5.000000
#
#        reservation_status reservation_status_date
# count               75166                   75166
# unique                  1                     805
# top             Check-Out              2015-12-08
# freq                75166                     243
# mean                  NaN                     NaN
# std                   NaN                     NaN
# min                   NaN                     NaN
# 25%                   NaN                     NaN
# 50%                   NaN                     NaN
# 75%                   NaN                     NaN
# max                   NaN                     NaN

# %%
# View Statistics for canceled 
dataset[dataset['is_canceled']==1].describe(include='all')
# Out:
#              hotel  is_canceled     lead_time  arrival_date_year  \
# count        44224      44224.0  44224.000000       44224.000000
# unique           2          NaN           NaN                NaN
# top     City Hotel          NaN           NaN                NaN
# freq         33102          NaN           NaN                NaN
# mean           NaN          1.0    144.848815        2016.171920
# std            NaN          0.0    118.624829           0.714557
# min            NaN          1.0      0.000000        2015.000000
# 25%            NaN          1.0     48.000000        2016.000000
# 50%            NaN          1.0    113.000000        2016.000000
# 75%            NaN          1.0    214.000000        2017.000000
# max            NaN          1.0    629.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               44224              44224.000000
# unique                 12                       NaN
# top                August                       NaN
# freq                 5239                       NaN
# mean                  NaN                 27.309696
# std                   NaN                 13.083155
# min                   NaN                  1.000000
# 25%                   NaN                 17.000000
# 50%                   NaN                 27.000000
# 75%                   NaN                 38.000000
# max                   NaN                 53.000000
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# count                44224.000000             44224.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                    15.728066                 0.925267
# std                      8.787969                 1.007468
# min                      1.000000                 0.000000
# 25%                      8.000000                 0.000000
# 50%                     16.000000                 1.000000
# 75%                     23.000000                 2.000000
# max                     31.000000                16.000000
#
#         stays_in_week_nights        adults      children        babies   meal  \
# count           44224.000000  44224.000000  44220.000000  44224.000000  44224
# unique                   NaN           NaN           NaN           NaN      5
# top                      NaN           NaN           NaN           NaN     BB
# freq                     NaN           NaN           NaN           NaN  34510
# mean                2.561912      1.901728      0.106513      0.003821    NaN
# std                 1.878296      0.678038      0.411352      0.062429    NaN
# min                 0.000000      0.000000      0.000000      0.000000    NaN
# 25%                 1.000000      2.000000      0.000000      0.000000    NaN
# 50%                 2.000000      2.000000      0.000000      0.000000    NaN
# 75%                 3.000000      2.000000      0.000000      0.000000    NaN
# max                40.000000     55.000000     10.000000      2.000000    NaN
#
#        country market_segment distribution_channel  is_repeated_guest  \
# count    44157          44224                44224       44224.000000
# unique     127              8                    5                NaN
# top        PRT      Online TA                TA/TO                NaN
# freq     27519          20739                40152                NaN
# mean       NaN            NaN                  NaN           0.012482
# std        NaN            NaN                  NaN           0.111024
# min        NaN            NaN                  NaN           0.000000
# 25%        NaN            NaN                  NaN           0.000000
# 50%        NaN            NaN                  NaN           0.000000
# 75%        NaN            NaN                  NaN           0.000000
# max        NaN            NaN                  NaN           1.000000
#
#         previous_cancellations  previous_bookings_not_canceled  \
# count             44224.000000                    44224.000000
# unique                     NaN                             NaN
# top                        NaN                             NaN
# freq                       NaN                             NaN
# mean                  0.208348                        0.025122
# std                   1.332346                        0.678941
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                  26.000000                       58.000000
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# count               44224              44224     44224.000000        44224
# unique                 10                 12              NaN            3
# top                     A                  A              NaN   No Deposit
# freq                33630              32948              NaN        29694
# mean                  NaN                NaN         0.098340          NaN
# std                   NaN                NaN         0.451008          NaN
# min                   NaN                NaN         0.000000          NaN
# 25%                   NaN                NaN         0.000000          NaN
# 50%                   NaN                NaN         0.000000          NaN
# 75%                   NaN                NaN         0.000000          NaN
# max                   NaN                NaN        16.000000          NaN
#
#                agent      company  days_in_waiting_list customer_type  \
# count   40194.000000  1191.000000          44224.000000         44224
# unique           NaN          NaN                   NaN             4
# top              NaN          NaN                   NaN     Transient
# freq             NaN          NaN                   NaN         36514
# mean       75.179927   183.371117              3.564083           NaN
# std       104.589834   128.226814             21.488768           NaN
# min         1.000000     9.000000              0.000000           NaN
# 25%         9.000000    67.000000              0.000000           NaN
# 50%         9.000000   169.000000              0.000000           NaN
# 75%       149.000000   270.000000              0.000000           NaN
# max       531.000000   543.000000            391.000000           NaN
#
#                  adr  required_car_parking_spaces  total_of_special_requests  \
# count   44224.000000                      44224.0               44224.000000
# unique           NaN                          NaN                        NaN
# top              NaN                          NaN                        NaN
# freq             NaN                          NaN                        NaN
# mean      104.964333                          0.0                   0.328826
# std        52.571142                          0.0                   0.649234
# min         0.000000                          0.0                   0.000000
# 25%        72.415000                          0.0                   0.000000
# 50%        96.200000                          0.0                   0.000000
# 75%       127.620000                          0.0                   0.000000
# max      5400.000000                          0.0                   5.000000
#
#        reservation_status reservation_status_date
# count               44224                   44224
# unique                  2                     902
# top              Canceled              2015-10-21
# freq                43017                    1373
# mean                  NaN                     NaN
# std                   NaN                     NaN
# min                   NaN                     NaN
# 25%                   NaN                     NaN
# 50%                   NaN                     NaN
# 75%                   NaN                     NaN
# max                   NaN                     NaN

# %% [markdown]
# ## Data Cleaning

# %%
# Copy raw dataset to df for further processing
df = dataset.copy()

# %%
# Convert reservation_status_date form object data type to datetime data type for date processing
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d').dt.strftime("%Y%m")

# %%
# Drop column(s) due to alot of missing entries (or pre-preprocessing column(s))
df = df.drop(['company'], axis=1)

# %%
# Drop rows with missing values
df = df.dropna().reset_index(drop=True)

# %%
# Check for nulls in dataset again after dropna command
df.isnull().any().any()
# Out:
# False

# %%
# Add column for lead_time_catg with varying lead time days for further segmentation analysis
# ____________
#leadTime_bin = np.array([0,1,2,3,4,5,6,7,14,21,30,45,60,90,120,180,270,300,365,765]) 
#leadTime_bin = np.array([0,5,6,7,14,21,30,45,60,90,120,180,270,300,365,765]) 
# ____________

leadTime_bin = np.array([0,6,7,14,21,30,45,60,90,120,180,270,300,365,765]) 
df["leadTime_catg"] = pd.cut(df['lead_time'], leadTime_bin)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0         13               2015               July
# 1  Resort Hotel            0         14               2015               July
# 2  Resort Hotel            0         14               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            1         85               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     1       1       0.0       0
# 1                        0                     2       2       0.0       0
# 2                        0                     2       2       0.0       0
# 3                        0                     2       2       0.0       0
# 4                        0                     3       2       0.0       0
#
#   meal country market_segment distribution_channel  is_repeated_guest  \
# 0   BB     GBR      Corporate            Corporate                  0
# 1   BB     GBR      Online TA                TA/TO                  0
# 2   BB     GBR      Online TA                TA/TO                  0
# 3   FB     PRT         Direct               Direct                  0
# 4   BB     PRT      Online TA                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  A
# 1                       0                               0                  A
# 2                       0                               0                  A
# 3                       0                               0                  C
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes deposit_type  agent  \
# 0                  A                0   No Deposit  304.0
# 1                  A                0   No Deposit  240.0
# 2                  A                0   No Deposit  240.0
# 3                  C                0   No Deposit  303.0
# 4                  A                0   No Deposit  240.0
#
#    days_in_waiting_list customer_type    adr  required_car_parking_spaces  \
# 0                     0     Transient   75.0                            0
# 1                     0     Transient   98.0                            0
# 2                     0     Transient   98.0                            0
# 3                     0     Transient  103.0                            0
# 4                     0     Transient   82.0                            0
#
#    total_of_special_requests reservation_status reservation_status_date  \
# 0                          0          Check-Out                  201507
# 1                          1          Check-Out                  201507
# 2                          1          Check-Out                  201507
# 3                          1          Check-Out                  201507
# 4                          1           Canceled                  201505
#
#   leadTime_catg
# 0       (7, 14]
# 1       (7, 14]
# 2       (7, 14]
# 3       (7, 14]
# 4      (60, 90]

# %%
df.shape
# Out:
# (102894, 32)

# %% [markdown]
# ## __1- Data Analysis - Lead time__

# %% [markdown]
# ### Prepare Data for Analysis

# %%
# Dataframe for all 'booked' rows
leadtime_booked = df[df['is_canceled']==0]
leadtime_booked[:10]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0         13               2015
# 1   Resort Hotel            0         14               2015
# 2   Resort Hotel            0         14               2015
# 3   Resort Hotel            0          9               2015
# 7   Resort Hotel            0         35               2015
# 8   Resort Hotel            0         68               2015
# 9   Resort Hotel            0         18               2015
# 10  Resort Hotel            0         37               2015
# 11  Resort Hotel            0         68               2015
# 12  Resort Hotel            0         37               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                July                        27                          1
# 1                July                        27                          1
# 2                July                        27                          1
# 3                July                        27                          1
# 7                July                        27                          1
# 8                July                        27                          1
# 9                July                        27                          1
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                         0                     1       1       0.0       0
# 1                         0                     2       2       0.0       0
# 2                         0                     2       2       0.0       0
# 3                         0                     2       2       0.0       0
# 7                         0                     4       2       0.0       0
# 8                         0                     4       2       0.0       0
# 9                         0                     4       2       1.0       0
# 10                        0                     4       2       0.0       0
# 11                        0                     4       2       0.0       0
# 12                        0                     4       2       0.0       0
#
#    meal country market_segment distribution_channel  is_repeated_guest  \
# 0    BB     GBR      Corporate            Corporate                  0
# 1    BB     GBR      Online TA                TA/TO                  0
# 2    BB     GBR      Online TA                TA/TO                  0
# 3    FB     PRT         Direct               Direct                  0
# 7    HB     PRT      Online TA                TA/TO                  0
# 8    BB     USA      Online TA                TA/TO                  0
# 9    HB     ESP      Online TA                TA/TO                  0
# 10   BB     PRT      Online TA                TA/TO                  0
# 11   BB     IRL      Online TA                TA/TO                  0
# 12   BB     PRT  Offline TA/TO                TA/TO                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                        0                               0                  A
# 1                        0                               0                  A
# 2                        0                               0                  A
# 3                        0                               0                  C
# 7                        0                               0                  D
# 8                        0                               0                  D
# 9                        0                               0                  G
# 10                       0                               0                  E
# 11                       0                               0                  D
# 12                       0                               0                  E
#
#    assigned_room_type  booking_changes deposit_type  agent  \
# 0                   A                0   No Deposit  304.0
# 1                   A                0   No Deposit  240.0
# 2                   A                0   No Deposit  240.0
# 3                   C                0   No Deposit  303.0
# 7                   D                0   No Deposit  240.0
# 8                   E                0   No Deposit  240.0
# 9                   G                1   No Deposit  241.0
# 10                  E                0   No Deposit  241.0
# 11                  E                0   No Deposit  240.0
# 12                  E                0   No Deposit    8.0
#
#     days_in_waiting_list customer_type     adr  required_car_parking_spaces  \
# 0                      0     Transient   75.00                            0
# 1                      0     Transient   98.00                            0
# 2                      0     Transient   98.00                            0
# 3                      0     Transient  103.00                            0
# 7                      0     Transient  145.00                            0
# 8                      0     Transient   97.00                            0
# 9                      0     Transient  154.77                            0
# 10                     0     Transient   94.71                            0
# 11                     0     Transient   97.00                            0
# 12                     0      Contract   97.50                            0
#
#     total_of_special_requests reservation_status reservation_status_date  \
# 0                           0          Check-Out                  201507
# 1                           1          Check-Out                  201507
# 2                           1          Check-Out                  201507
# 3                           1          Check-Out                  201507
# 7                           0          Check-Out                  201507
# 8                           3          Check-Out                  201507
# 9                           1          Check-Out                  201507
# 10                          0          Check-Out                  201507
# 11                          3          Check-Out                  201507
# 12                          0          Check-Out                  201507
#
#    leadTime_catg
# 0        (7, 14]
# 1        (7, 14]
# 2        (7, 14]
# 3        (7, 14]
# 7       (30, 45]
# 8       (60, 90]
# 9       (14, 21]
# 10      (30, 45]
# 11      (60, 90]
# 12      (30, 45]

# %%
# Dataframe for all 'canceled' rows
leadtime_cancl = df[df['is_canceled']==1]
leadtime_cancl[:10]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 4   Resort Hotel            1         85               2015
# 5   Resort Hotel            1         75               2015
# 6   Resort Hotel            1         23               2015
# 22  Resort Hotel            1         60               2015
# 27  Resort Hotel            1         45               2015
# 28  Resort Hotel            1         40               2015
# 31  Resort Hotel            1         43               2015
# 33  Resort Hotel            1         45               2015
# 37  Resort Hotel            1         47               2015
# 53  Resort Hotel            1          3               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 4                July                        27                          1
# 5                July                        27                          1
# 6                July                        27                          1
# 22               July                        27                          1
# 27               July                        27                          2
# 28               July                        27                          2
# 31               July                        27                          2
# 33               July                        27                          2
# 37               July                        27                          2
# 53               July                        27                          2
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 4                         0                     3       2       0.0       0
# 5                         0                     3       2       0.0       0
# 6                         0                     4       2       0.0       0
# 22                        2                     5       2       0.0       0
# 27                        1                     3       3       0.0       0
# 28                        1                     3       3       0.0       0
# 31                        1                     3       3       0.0       0
# 33                        2                     3       2       0.0       0
# 37                        2                     5       2       2.0       0
# 53                        0                     3       2       0.0       0
#
#    meal country market_segment distribution_channel  is_repeated_guest  \
# 4    BB     PRT      Online TA                TA/TO                  0
# 5    HB     PRT  Offline TA/TO                TA/TO                  0
# 6    BB     PRT      Online TA                TA/TO                  0
# 22   BB     PRT      Online TA                TA/TO                  0
# 27   BB     PRT      Online TA                TA/TO                  0
# 28   BB     PRT      Online TA                TA/TO                  0
# 31   BB     PRT      Online TA                TA/TO                  0
# 33   BB     PRT      Online TA                TA/TO                  0
# 37   BB     PRT      Online TA                TA/TO                  0
# 53   HB     PRT      Online TA                TA/TO                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 4                        0                               0                  A
# 5                        0                               0                  D
# 6                        0                               0                  E
# 22                       0                               0                  E
# 27                       0                               0                  D
# 28                       0                               0                  D
# 31                       0                               0                  D
# 33                       0                               0                  G
# 37                       0                               0                  G
# 53                       0                               0                  A
#
#    assigned_room_type  booking_changes deposit_type  agent  \
# 4                   A                0   No Deposit  240.0
# 5                   D                0   No Deposit   15.0
# 6                   E                0   No Deposit  240.0
# 22                  E                0   No Deposit  240.0
# 27                  D                0   No Deposit  241.0
# 28                  D                0   No Deposit  241.0
# 31                  D                0   No Deposit  241.0
# 33                  G                0   No Deposit  241.0
# 37                  G                0   No Deposit  240.0
# 53                  A                0   No Deposit  240.0
#
#     days_in_waiting_list customer_type     adr  required_car_parking_spaces  \
# 4                      0     Transient   82.00                            0
# 5                      0     Transient  105.50                            0
# 6                      0     Transient  123.00                            0
# 22                     0     Transient  107.00                            0
# 27                     0     Transient  108.80                            0
# 28                     0     Transient  108.80                            0
# 31                     0     Transient  108.80                            0
# 33                     0     Transient  117.81                            0
# 37                     0     Transient  153.00                            0
# 53                     0     Transient  136.33                            0
#
#     total_of_special_requests reservation_status reservation_status_date  \
# 4                           1           Canceled                  201505
# 5                           0           Canceled                  201504
# 6                           0           Canceled                  201506
# 22                          2           Canceled                  201505
# 27                          1           Canceled                  201505
# 28                          1           Canceled                  201506
# 31                          0           Canceled                  201505
# 33                          0           Canceled                  201505
# 37                          0           Canceled                  201506
# 53                          2           Canceled                  201506
#
#    leadTime_catg
# 4       (60, 90]
# 5       (60, 90]
# 6       (21, 30]
# 22      (45, 60]
# 27      (30, 45]
# 28      (30, 45]
# 31      (30, 45]
# 33      (30, 45]
# 37      (45, 60]
# 53        (0, 6]

# %%
# Comparing distribuions between Bookings and Cancellations
sns.distplot(leadtime_booked['lead_time'], color='blue', label='Booked')
sns.distplot(leadtime_cancl['lead_time'], color='red', label='Canceled')
plt.axvline(np.mean(leadtime_cancl['lead_time']), color='red', linestyle = 'dashed', label='Cancel Mean')
plt.axvline(np.mean(leadtime_booked['lead_time']), color='blue', linestyle = 'dashed', label='Booked Mean')

plt.legend()
plt.show()

# %%
# Statistics for 'booked' lead time
leadtime_booked['lead_time'].describe()
# Out:
# count    62733.000000
# mean        87.817162
# std         91.600142
# min          0.000000
# 25%         15.000000
# 50%         57.000000
# 75%        135.000000
# max        542.000000
# Name: lead_time, dtype: float64

# %%
# Statistics for 'canceled' lead time
leadtime_cancl['lead_time'].describe()
# Out:
# count    40161.000000
# mean       149.108613
# std        119.627904
# min          0.000000
# 25%         52.000000
# 50%        118.000000
# 75%        220.000000
# max        629.000000
# Name: lead_time, dtype: float64

# %%
# Percentage Difference
(np.mean(leadtime_cancl['lead_time'])/np.mean(leadtime_booked['lead_time']) -1)*100
# Out:
# 69.7943887961897

# %% [markdown]
# #### Prepare Data for Analysis | Observations

# %% [markdown]
# - For 'all' reservations, the mean lead time for canceled reservations is __69.7%__ greater than booked mean lead time.
# - The data distribution is similar, however, the data is right-skewed = __non-normal distribution__.
#     - Based on intial analysis, is appears that lead time effects cancellations
#
#       __NOTE:__ We will confirm this initial observation by running a statistical test.

# %% [markdown]
# ### Check Assumptions

# %% [markdown]
# #### Check Sample Size(s)

# %%
# Size of samples
print(f"Sample Sizes: {len(leadtime_booked), len(leadtime_cancl)}")
# Out:
# Sample Sizes: (62733, 40161)

# %% [markdown]
# #### Test for Normality
#
# (If) Data Is Gaussian (normal distribution): Use Parametric Statistical Methods.
#
# (Else:) Use Nonparametric Statistical Methods.

# %% [markdown]
# #### Visual Normality Checks

# %%
# Comapring distribuions between Bookings and Cancelations > 180 days
sns.distplot(leadtime_booked['lead_time'], label='Booked')
sns.distplot(leadtime_cancl['lead_time'], label='Canceled')

plt.legend()
plt.show()

# %% [markdown]
# > __Shown:__
# - The data distribution is similar, however, the data is right-skewed - __not a normal distribution__.

# %%
# Normality Check - Booked?
# Visual Normality Tests: Using Q-Q Plot (Quantile-Quantile Plot)
sm.graphics.qqplot(leadtime_booked['lead_time'], line='s');

# %%
# Normality Check - Canceled?
# Visual Normality Tests: Using Q-Q Plot (Quantile-Quantile Plot)
sm.graphics.qqplot(leadtime_cancl['lead_time'], line='s');

# %% [markdown]
# - Q-Q plots show a __non-normal__ distributions as the data points extend away from the red line.

# %% [markdown]
# #### Statistical Normality Checks

# %% [markdown]
# > In the SciPy implementation of these tests, you can interpret the p value as follows:
# - p <= alpha: reject H0, not normal.
# - p > alpha: fail to reject H0, normal.

# %%
# Normality Check?
# Statistical Normality Tests: Using Shapiro-Wilk Test 
fs.shapiro_test(leadtime_booked['lead_time'],leadtime_cancl['lead_time'])
# Out:
# Statistical Normality Tests: Using Shapiro-Wilk Test
# _____
# Statistic: 0.8479, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)
#
# Statistic: 0.9127, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)
# C:\Users\deon\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# Normality Check?
# Statistical Normality Tests: Using KS Test

fs.ks_test(leadtime_booked['lead_time'], "norm")
fs.ks_test(leadtime_cancl['lead_time'], "norm")
# Out:
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 0.9024, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution
#
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 0.9849, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution

# %%
# Normality Check?
# Statistical Normality Tests: Using Anderson-Darling Test
from scipy.stats import anderson

result = anderson(leadtime_cancl['lead_time'])
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        print('%.3f: %.3f, data looks normal ( __Fail to Reject H0__ )' % (sl, cv))
    else:
        print('%.3f: %.3f, data does not look normal ( __Reject H0__ )' % (sl, cv))
# Out:
# Statistic: 957.986
# 15.000: 0.576, data does not look normal ( __Reject H0__ )
# 10.000: 0.656, data does not look normal ( __Reject H0__ )
# 5.000: 0.787, data does not look normal ( __Reject H0__ )
# 2.500: 0.918, data does not look normal ( __Reject H0__ )
# 1.000: 1.092, data does not look normal ( __Reject H0__ )

# %%
# Normality Check?
# Statistical Normality Tests: Using Anderson-Darling Test
fs.anderson_test(leadtime_booked['lead_time'],leadtime_cancl['lead_time'])
# Out:
# Statistical Normality Tests: Using Anderson-Darling Test
# _____
#
# Statistic: 2756.699
# 15.000: 0.576 __Reject H0__   Data does NOT look normal
# 10.000: 0.656 __Reject H0__   Data does NOT look normal
# 5.000: 0.787 __Reject H0__   Data does NOT look normal
# 2.500: 0.918 __Reject H0__   Data does NOT look normal
# 1.000: 1.092 __Reject H0__   Data does NOT look normal
#
# Statistic: 957.986
# 15.000: 0.576 __Reject H0__   Data does NOT look normal
# 10.000: 0.656 __Reject H0__   Data does NOT look normal
# 5.000: 0.787 __Reject H0__   Data does NOT look normal
# 2.500: 0.918 __Reject H0__   Data does NOT look normal
# 1.000: 1.092 __Reject H0__   Data does NOT look normal

# %%
# Normality Check?
# Statistical Normality Tests: Using D’Agostino’s K^2 Test

from scipy.stats import normaltest

stat, p = normaltest(leadtime_cancl['lead_time'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
if p > alpha:
    print(f"p-value is {np.round((p), 4)}, __Fail to Reject H0__  Sample looks Gaussian (normal distribution)")
else:
    print(f"p-value is {np.round((p), 4)}, __Reject H0__  Sample does NOT look Gaussian (non-normal distribution)")
# Out:
# Statistics=5370.271, p=0.000
# p-value is 0.0, __Reject H0__  Sample does NOT look Gaussian (non-normal distribution)

# %% [markdown]
# #### Observation: Statistical Normality Checks
# - All tests __Reject H0__ which indicates that the data does __not__ look normal.  Therefore, samples do __not__ follow a Gaussian distribution.

# %% [markdown]
# #### Test for Variance
# - The variance criterion holds true when p > a (where a is the probability threshold usually set to 0.05)

# %%
# Variance Check?
# Statistical Variance Tests: Using Levene Variance Test 
fs.levene_test(leadtime_booked['lead_time'], leadtime_cancl['lead_time'])
# Out:
# Statistic: 3126.1782, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__     Variances are NOT equal

# %% [markdown]
# #### Observations | Check Assumptions:
# - Plotting sample datasets appear to be right-skewed, suggesting data has a non-normal distribution.
# - Performing several statistical tests for normality, p < 0.05 failing to conform to the normality criterion.
# - Performing statistical test for variance, p < 0.05 failing to conform to the variance criterion.
# - QQ plot distribution does not confirm to the line, suggesting a non-normal distribution.

# %% [markdown]
# ### Perform Statistic Test

# %% [markdown]
# __Which Statistic Test to Run?__
# - One of the assumptions of the two sample t-test is that both samples are normally distributed. I can however, thanks to the central limit theorem, bypass this assumption given that both sample sizes are relatively large. The central limit theorem states that given a sufficiently large sample size from a population (usually more than 30) with a finite level of variance, the mean of all samples from the same population will be approximately equal to the mean of the population.
#
# - Another assumption is that the variances. of the two groups you are measuring are equal in the population. To test this assumption i will use the Levene test, which its null hypothesis is that all input samples are from populations with equal variances.
#
# ####  Welch's t-test
#
# > Welch's t-test, or unequal variances t-test, is a two-sample location test which is used to test the hypothesis that two populations have equal means.
#
# - Normality & Variance criteria: __Both False__
# - Based on above assumptions and observations, we will perform the following:
#
#     - Parametric t-test: __ttest_ind() method by passing the argument equal_var = False__ (Welch's Test)
#     - NOTE: It might be the case that your sample data is large enough to apply parametric t-test although the normality criterion is violated.

# %% [markdown]
# __Two-Sample t-test__

# %%
# Calculate t-statistic for samples, using Two-Sample T-test (independent)
# In case of unequal variances a better option is to call the ttest_ind() method by passing the argument equal_var = False

stat, p = stats.ttest_ind(leadtime_booked['lead_time'], leadtime_cancl['lead_time'], equal_var = False)
print(f"Statistic for sample is {round(stat, 4)} and the p-value is {p}: Rounded the p-value is {np.round((p), 4)}")

if p <= alpha:
    print(f"p-value is {np.round((p), 4)},  Reject the Null hypothesis")
else:
    print(f"p-value is {np.round((p), 4)},  Fail to reject the Null hypothesis")
# Out:
# Statistic for sample is -87.5514 and the p-value is 0.0: Rounded the p-value is 0.0
# p-value is 0.0,  Reject the Null hypothesis

# %% [markdown]
# __Welch's t-test__

# %%
# Calculate statistic for samples, using Welch's T-test which is maintained in the flatirons.py file
p = fs.p_value_welch_ttest(leadtime_booked['lead_time'], leadtime_cancl['lead_time'], two_sided=True)
print(f"The p-value is {p}: Rounded the p-value is {np.round((p), 4)}")

if p <= alpha:
    print(f"p-value is {np.round((p), 4)} - Reject the Null hypothesis")
else:
    print(f"p-value is {np.round((p), 4)} - Fail to reject the Null hypothesis")
# Out:
# The p-value is 0.0: Rounded the p-value is 0.0
# p-value is 0.0 - Reject the Null hypothesis

# %% [markdown]
# > __Why, Welch's t-test? ....__
# - URL: https://www.statisticshowto.com/welchs-test-for-unequal-variances/
# - With a significance level of 5% (alpha), I reject the null hypothesis and accept that the samples are not from populations from equal variances. Fortunately, there is a variation of the two sample t-test when samples do not conform to the equal variance assumption. It’s called Welch’s t-test, and it is more reliable when the two samples have unequal variances and/or unequal sample sizes. Since the samples have unequal variances and unequal sample sizes, this is the test I chose to perform hypothesis testing.

# %% [markdown]
# #### Observations | Perform Statistic Test :
# - Since p-value is 0.0 < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that booking in advance does have a statistical significant effect on the number of cancellations.

# %% [markdown]
# ### Perform Effect Size (Cohen's d) Test

# %% [markdown]
# > Cohen'd Test is one of the most common ways to measure effect size. An effect size is how large an effect of something is.

# %%
# Calculate effect size for samples, using Cohen's (D) used to indicate the standardised difference between two means.
cohens_d_results = fs.cohens_d(leadtime_booked['lead_time'], leadtime_cancl['lead_time'])
print(f"The effect size (d) is {cohens_d_results}: Rounded (d) is {np.round((cohens_d_results), 4)}")
# Out:
# The effect size (d) is -0.5924896149544137: Rounded (d) is -0.5925

# %% [markdown]
# #### Perform Effect Size | Observation:
# -  Cohen's D, how to interpret results:
#
#     - d=0.2 be considered a 'small' effect size
#
#     - d=0.5 represents a 'medium' effect size
#
#     - d=0.8 a 'large' effect size.

# %% [markdown]
# > __0.5925__, is a __medium effect size__ according to chart above.

# %%
# Sample size
print(f"Sample Sizes: {len(leadtime_booked['lead_time']), len(leadtime_cancl['lead_time'])}")
# Out:
# Sample Sizes: (62733, 40161)

# %%
#Calculate sample size required
from statsmodels.stats.power import TTestIndPower, TTestPower
power_analysis = TTestIndPower()
power_analysis.solve_power(effect_size=-0.5925, alpha=.05, power=.8)
# Out:
# 45.69618568956268

# %%
#Calculate minimum effect size to satisfy desired alpha and power as well as respect sample size limitations
power_analysis.solve_power(nobs1=45.6961, alpha=.05, power=.8)
# Out:
# 0.5925002822413228

# %% [markdown]
# ### __Conclusions: 1- Data Analysis__
# - __p-value:__ Rounded the p-value is 0.0
# - __effect size:__ d=__0.5925__, is a __medium effect size__
# - __Observations:__ Since p-value is 0.0 < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that lead time has a statistical significant effect on cancellations." Since the mean of the cancellation sample is bigger than the booked sample the conclusion is that booking far in advance increases the probability of cancellation.

# %% [markdown]
# ## __2- Data Analysis - Lead time > 180 days__

# %% [markdown]
# ### Prepare Data for Analysis

# %%
# Rows of reservations booked > 180 days
leadtime_more_180_booked = df[(df['lead_time'] >= 180) &  (df['is_canceled'] == 0)]
leadtime_more_180_booked[:10]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 71   Resort Hotel            0        364               2015
# 74   Resort Hotel            0        324               2015
# 167  Resort Hotel            0        258               2015
# 203  Resort Hotel            0        394               2015
# 222  Resort Hotel            0        366               2015
# 223  Resort Hotel            0        249               2015
# 257  Resort Hotel            0        304               2015
# 362  Resort Hotel            0        317               2015
# 457  Resort Hotel            0        315               2015
# 757  Resort Hotel            0        286               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 71                July                        27                          3
# 74                July                        27                          3
# 167               July                        28                          6
# 203               July                        28                          8
# 222               July                        28                          9
# 223               July                        28                          9
# 257               July                        28                         11
# 362               July                        29                         14
# 457               July                        29                         17
# 757               July                        31                         31
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 71                         3                     7       2       0.0       0
# 74                         4                    10       2       0.0       0
# 167                        2                     5       2       0.0       0
# 203                        2                     5       2       0.0       0
# 222                        2                     5       2       0.0       0
# 223                        2                     5       2       0.0       0
# 257                        2                     4       2       0.0       1
# 362                        1                     5       2       2.0       0
# 457                        1                     2       2       0.0       0
# 757                        2                     2       1       0.0       0
#
#     meal country market_segment distribution_channel  is_repeated_guest  \
# 71    BB     GBR  Offline TA/TO                TA/TO                  0
# 74    HB     GBR  Offline TA/TO                TA/TO                  0
# 167   BB     GBR  Offline TA/TO                TA/TO                  0
# 203   HB     GBR  Offline TA/TO                TA/TO                  0
# 222   HB     GBR  Offline TA/TO                TA/TO                  0
# 223   HB     PRT      Online TA                TA/TO                  0
# 257   BB     PRT         Direct                TA/TO                  0
# 362   HB     PRT         Direct                TA/TO                  0
# 457   BB     IRL  Offline TA/TO                TA/TO                  0
# 757   BB     IRL         Direct               Direct                  0
#
#      previous_cancellations  previous_bookings_not_canceled  \
# 71                        0                               0
# 74                        0                               0
# 167                       0                               0
# 203                       0                               0
# 222                       0                               0
# 223                       0                               0
# 257                       0                               0
# 362                       0                               0
# 457                       0                               0
# 757                       0                               0
#
#     reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 71                   A                  A                0   No Deposit
# 74                   E                  E                0   No Deposit
# 167                  A                  A                0   No Deposit
# 203                  D                  D                0   No Deposit
# 222                  E                  E                0   No Deposit
# 223                  A                  A                0   No Deposit
# 257                  A                  A                1   No Deposit
# 362                  H                  G                1   No Deposit
# 457                  A                  D                0   No Deposit
# 757                  A                  A                0   No Deposit
#
#      agent  days_in_waiting_list customer_type     adr  \
# 71    40.0                     0      Contract   55.68
# 74    40.0                     0      Contract  134.73
# 167    2.0                     0      Contract   47.25
# 203   40.0                     0      Contract   89.68
# 222   40.0                     0      Contract  134.73
# 223  240.0                     0     Transient  112.00
# 257  240.0                     0     Transient   90.67
# 362  240.0                     0     Transient  230.67
# 457  171.0                     0     Transient   96.30
# 757    2.0                     0     Transient   57.60
#
#      required_car_parking_spaces  total_of_special_requests  \
# 71                             0                          0
# 74                             0                          0
# 167                            0                          0
# 203                            0                          0
# 222                            0                          0
# 223                            0                          1
# 257                            0                          1
# 362                            1                          2
# 457                            0                          0
# 757                            0                          0
#
#     reservation_status reservation_status_date leadTime_catg
# 71           Check-Out                  201507    (300, 365]
# 74           Check-Out                  201507    (300, 365]
# 167          Check-Out                  201507    (180, 270]
# 203          Check-Out                  201507    (365, 765]
# 222          Check-Out                  201507    (365, 765]
# 223          Check-Out                  201507    (180, 270]
# 257          Check-Out                  201507    (300, 365]
# 362          Check-Out                  201507    (300, 365]
# 457          Check-Out                  201507    (300, 365]
# 757          Check-Out                  201508    (270, 300]

# %%
# Rows of reservations canceled > 180 days
leadtime_more_180_cancl = df[(df['lead_time'] >= 180) &  (df['is_canceled'] == 1)]
leadtime_more_180_cancl[:10]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 70    Resort Hotel            1        368               2015
# 189   Resort Hotel            1        292               2015
# 201   Resort Hotel            1        280               2015
# 336   Resort Hotel            1        321               2015
# 600   Resort Hotel            1        312               2015
# 637   Resort Hotel            1        299               2015
# 681   Resort Hotel            1        298               2015
# 793   Resort Hotel            1        327               2015
# 1296  Resort Hotel            1        346               2015
# 1370  Resort Hotel            1        297               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 70                 July                        27                          3
# 189                July                        28                          7
# 201                July                        28                          8
# 336                July                        29                         13
# 600                July                        30                         24
# 637                July                        30                         25
# 681                July                        31                         27
# 793              August                        32                          2
# 1296             August                        36                         30
# 1370          September                        36                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 70                          3                     7       2       0.0       0
# 189                         2                     5       2       0.0       0
# 201                         2                     5       2       1.0       0
# 336                         1                     4       2       0.0       0
# 600                         4                    10       3       0.0       0
# 637                         2                     5       2       1.0       0
# 681                         1                     5       3       0.0       0
# 793                         4                    10       2       0.0       0
# 1296                        4                     8       2       0.0       0
# 1370                        1                     3       2       0.0       0
#
#      meal country market_segment distribution_channel  is_repeated_guest  \
# 70     BB     PRT  Offline TA/TO                TA/TO                  0
# 189    BB     PRT  Offline TA/TO                TA/TO                  0
# 201    HB     PRT  Offline TA/TO                TA/TO                  0
# 336    HB     PRT         Direct                TA/TO                  0
# 600    BB     PRT  Offline TA/TO                TA/TO                  0
# 637    BB     PRT      Online TA                TA/TO                  0
# 681    HB     PRT  Offline TA/TO                TA/TO                  0
# 793    BB     PRT  Offline TA/TO                TA/TO                  0
# 1296   BB     PRT  Offline TA/TO                TA/TO                  0
# 1370   BB     PRT         Direct                TA/TO                  0
#
#       previous_cancellations  previous_bookings_not_canceled  \
# 70                         0                               0
# 189                        0                               0
# 201                        0                               0
# 336                        0                               0
# 600                        0                               0
# 637                        0                               0
# 681                        0                               0
# 793                        0                               0
# 1296                       0                               0
# 1370                       0                               0
#
#      reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 70                    A                  A                0   No Deposit
# 189                   A                  A                0   No Deposit
# 201                   D                  D                0   No Deposit
# 336                   A                  A                0   No Deposit
# 600                   A                  A                0   No Deposit
# 637                   A                  A                0   No Deposit
# 681                   A                  A                0   No Deposit
# 793                   D                  D                0   No Deposit
# 1296                  A                  A                0   No Deposit
# 1370                  A                  A                0   No Deposit
#
#       agent  days_in_waiting_list customer_type     adr  \
# 70     40.0                     0      Contract   55.68
# 189     2.0                     0      Contract   47.25
# 201    40.0                     0      Contract  112.00
# 336   240.0                     0     Transient  132.80
# 600    40.0                     0      Contract  121.98
# 637   240.0                     0     Transient  149.00
# 681   175.0                     0     Transient  183.45
# 793    40.0                     0      Contract  104.55
# 1296  171.0                     0     Transient   96.30
# 1370  240.0                     0     Transient    0.00
#
#       required_car_parking_spaces  total_of_special_requests  \
# 70                              0                          0
# 189                             0                          0
# 201                             0                          1
# 336                             0                          1
# 600                             0                          1
# 637                             0                          1
# 681                             0                          1
# 793                             0                          0
# 1296                            0                          0
# 1370                            0                          0
#
#      reservation_status reservation_status_date leadTime_catg
# 70             Canceled                  201505    (365, 765]
# 189            Canceled                  201503    (270, 300]
# 201            Canceled                  201504    (270, 300]
# 336            Canceled                  201503    (300, 365]
# 600            Canceled                  201507    (300, 365]
# 637            Canceled                  201503    (270, 300]
# 681            Canceled                  201503    (270, 300]
# 793            Canceled                  201504    (300, 365]
# 1296           Canceled                  201508    (300, 365]
# 1370           Canceled                  201411    (270, 300]

# %%
# View Statistics for booked > 180 days
leadtime_more_180_booked.describe(include='all')
# Out:
#              hotel  is_canceled    lead_time  arrival_date_year  \
# count         9861       9861.0  9861.000000        9861.000000
# unique           2          NaN          NaN                NaN
# top     City Hotel          NaN          NaN                NaN
# freq          6033          NaN          NaN                NaN
# mean           NaN          0.0   257.805902        2016.292972
# std            NaN          0.0    71.039042           0.647244
# min            NaN          0.0   180.000000        2015.000000
# 25%            NaN          0.0   204.000000        2016.000000
# 50%            NaN          0.0   237.000000        2016.000000
# 75%            NaN          0.0   292.000000        2017.000000
# max            NaN          0.0   542.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count                9861               9861.000000
# unique                 12                       NaN
# top                  July                       NaN
# freq                 1736                       NaN
# mean                  NaN                 29.923740
# std                   NaN                  9.258682
# min                   NaN                  1.000000
# 25%                   NaN                 23.000000
# 50%                   NaN                 30.000000
# 75%                   NaN                 37.000000
# max                   NaN                 53.000000
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 9861.000000              9861.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                    16.133658                 1.222290
# std                      8.768998                 1.136645
# min                      1.000000                 0.000000
# 25%                      9.000000                 0.000000
# 50%                     17.000000                 1.000000
# 75%                     24.000000                 2.000000
# max                     31.000000                14.000000
#
#         stays_in_week_nights       adults     children       babies  meal  \
# count            9861.000000  9861.000000  9861.000000  9861.000000  9861
# unique                   NaN          NaN          NaN          NaN     5
# top                      NaN          NaN          NaN          NaN    BB
# freq                     NaN          NaN          NaN          NaN  6353
# mean                3.273907     1.896258     0.092688     0.007809   NaN
# std                 2.291823     0.439536     0.374556     0.089169   NaN
# min                 0.000000     0.000000     0.000000     0.000000   NaN
# 25%                 2.000000     2.000000     0.000000     0.000000   NaN
# 50%                 3.000000     2.000000     0.000000     0.000000   NaN
# 75%                 5.000000     2.000000     0.000000     0.000000   NaN
# max                34.000000     4.000000     3.000000     2.000000   NaN
#
#        country market_segment distribution_channel  is_repeated_guest  \
# count     9861           9861                 9861        9861.000000
# unique      79              6                    3                NaN
# top        GBR  Offline TA/TO                TA/TO                NaN
# freq      2227           3919                 9221                NaN
# mean       NaN            NaN                  NaN           0.004056
# std        NaN            NaN                  NaN           0.063564
# min        NaN            NaN                  NaN           0.000000
# 25%        NaN            NaN                  NaN           0.000000
# 50%        NaN            NaN                  NaN           0.000000
# 75%        NaN            NaN                  NaN           0.000000
# max        NaN            NaN                  NaN           1.000000
#
#         previous_cancellations  previous_bookings_not_canceled  \
# count              9861.000000                     9861.000000
# unique                     NaN                             NaN
# top                        NaN                             NaN
# freq                       NaN                             NaN
# mean                  0.000101                        0.010547
# std                   0.010070                        0.122061
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   0.000000                        0.000000
# max                   1.000000                        4.000000
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# count                9861               9861      9861.000000         9861
# unique                  8                 10              NaN            3
# top                     A                  A              NaN   No Deposit
# freq                 7296               6342              NaN         9840
# mean                  NaN                NaN         0.354224          NaN
# std                   NaN                NaN         0.802487          NaN
# min                   NaN                NaN         0.000000          NaN
# 25%                   NaN                NaN         0.000000          NaN
# 50%                   NaN                NaN         0.000000          NaN
# 75%                   NaN                NaN         0.000000          NaN
# max                   NaN                NaN        18.000000          NaN
#
#               agent  days_in_waiting_list    customer_type          adr  \
# count   9861.000000           9861.000000             9861  9861.000000
# unique          NaN                   NaN                4          NaN
# top             NaN                   NaN  Transient-Party          NaN
# freq            NaN                   NaN             4733          NaN
# mean      98.503701              7.054964              NaN    98.638944
# std      118.352002             35.495033              NaN    37.795373
# min        1.000000              0.000000              NaN    -6.380000
# 25%        9.000000              0.000000              NaN    74.250000
# 50%       21.000000              0.000000              NaN    95.400000
# 75%      240.000000              0.000000              NaN   115.000000
# max      527.000000            379.000000              NaN   326.500000
#
#         required_car_parking_spaces  total_of_special_requests  \
# count                   9861.000000                9861.000000
# unique                          NaN                        NaN
# top                             NaN                        NaN
# freq                            NaN                        NaN
# mean                       0.048068                   0.764527
# std                        0.217214                   0.855316
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   1.000000
# 75%                        0.000000                   1.000000
# max                        3.000000                   5.000000
#
#        reservation_status reservation_status_date leadTime_catg
# count                9861                    9861          9861
# unique                  1                      27             5
# top             Check-Out                  201707    (180, 270]
# freq                 9861                     954          6432
# mean                  NaN                     NaN           NaN
# std                   NaN                     NaN           NaN
# min                   NaN                     NaN           NaN
# 25%                   NaN                     NaN           NaN
# 50%                   NaN                     NaN           NaN
# 75%                   NaN                     NaN           NaN
# max                   NaN                     NaN           NaN

# %%
# View Statistics for canceled > 180 days
leadtime_more_180_cancl.describe(include='all')
# Out:
#              hotel  is_canceled     lead_time  arrival_date_year  \
# count        13383      13383.0  13383.000000       13383.000000
# unique           2          NaN           NaN                NaN
# top     City Hotel          NaN           NaN                NaN
# freq         10500          NaN           NaN                NaN
# mean           NaN          1.0    290.667264        2016.060525
# std            NaN          0.0     87.852588           0.733253
# min            NaN          1.0    180.000000        2015.000000
# 25%            NaN          1.0    220.000000        2016.000000
# 50%            NaN          1.0    277.000000        2016.000000
# 75%            NaN          1.0    332.000000        2017.000000
# max            NaN          1.0    629.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               13383              13383.000000
# unique                 12                       NaN
# top             September                       NaN
# freq                 2049                       NaN
# mean                  NaN                 30.816558
# std                   NaN                 10.760086
# min                   NaN                  1.000000
# 25%                   NaN                 23.000000
# 50%                   NaN                 32.000000
# 75%                   NaN                 39.000000
# max                   NaN                 53.000000
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# count                13383.000000             13383.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                    15.275349                 0.898603
# std                      8.730297                 1.025144
# min                      1.000000                 0.000000
# 25%                      8.000000                 0.000000
# 50%                     16.000000                 1.000000
# 75%                     22.000000                 2.000000
# max                     31.000000                16.000000
#
#         stays_in_week_nights        adults      children        babies   meal  \
# count           13383.000000  13383.000000  13383.000000  13383.000000  13383
# unique                   NaN           NaN           NaN           NaN      5
# top                      NaN           NaN           NaN           NaN     BB
# freq                     NaN           NaN           NaN           NaN  10702
# mean                2.633939      1.958455      0.069416      0.002466    NaN
# std                 1.883461      0.570071      0.329231      0.051082    NaN
# min                 0.000000      0.000000      0.000000      0.000000    NaN
# 25%                 2.000000      2.000000      0.000000      0.000000    NaN
# 50%                 2.000000      2.000000      0.000000      0.000000    NaN
# 75%                 3.000000      2.000000      0.000000      0.000000    NaN
# max                40.000000     26.000000      3.000000      2.000000    NaN
#
#        country market_segment distribution_channel  is_repeated_guest  \
# count    13383          13383                13383       13383.000000
# unique      82              5                    4                NaN
# top        PRT         Groups                TA/TO                NaN
# freq     10026           5802                13092                NaN
# mean       NaN            NaN                  NaN           0.015990
# std        NaN            NaN                  NaN           0.125443
# min        NaN            NaN                  NaN           0.000000
# 25%        NaN            NaN                  NaN           0.000000
# 50%        NaN            NaN                  NaN           0.000000
# 75%        NaN            NaN                  NaN           0.000000
# max        NaN            NaN                  NaN           1.000000
#
#         previous_cancellations  previous_bookings_not_canceled  \
# count             13383.000000                    13383.000000
# unique                     NaN                             NaN
# top                        NaN                             NaN
# freq                       NaN                             NaN
# mean                  0.423149                        0.000523
# std                   1.972852                        0.025928
# min                   0.000000                        0.000000
# 25%                   0.000000                        0.000000
# 50%                   0.000000                        0.000000
# 75%                   1.000000                        0.000000
# max                  26.000000                        2.000000
#
#        reserved_room_type assigned_room_type  booking_changes deposit_type  \
# count               13383              13383     13383.000000        13383
# unique                  8                  9              NaN            3
# top                     A                  A              NaN   Non Refund
# freq                11536              11438              NaN         6875
# mean                  NaN                NaN         0.087051          NaN
# std                   NaN                NaN         0.451635          NaN
# min                   NaN                NaN         0.000000          NaN
# 25%                   NaN                NaN         0.000000          NaN
# 50%                   NaN                NaN         0.000000          NaN
# 75%                   NaN                NaN         0.000000          NaN
# max                   NaN                NaN        16.000000          NaN
#
#                agent  days_in_waiting_list customer_type           adr  \
# count   13383.000000          13383.000000         13383  13383.000000
# unique           NaN                   NaN             4           NaN
# top              NaN                   NaN     Transient           NaN
# freq             NaN                   NaN          9928           NaN
# mean       63.518942              7.813495           NaN     90.403085
# std        98.250463             35.608279           NaN     37.643501
# min         1.000000              0.000000           NaN      0.000000
# 25%         1.000000              0.000000           NaN     62.000000
# 50%         9.000000              0.000000           NaN     85.000000
# 75%        83.000000              0.000000           NaN    109.000000
# max       472.000000            391.000000           NaN    450.000000
#
#         required_car_parking_spaces  total_of_special_requests  \
# count                       13383.0               13383.000000
# unique                          NaN                        NaN
# top                             NaN                        NaN
# freq                            NaN                        NaN
# mean                            0.0                   0.242995
# std                             0.0                   0.587812
# min                             0.0                   0.000000
# 25%                             0.0                   0.000000
# 50%                             0.0                   0.000000
# 75%                             0.0                   0.000000
# max                             0.0                   4.000000
#
#        reservation_status reservation_status_date leadTime_catg
# count               13383                   13383         13383
# unique                  2                      34             5
# top              Canceled                  201510    (180, 270]
# freq                13306                    1697          6024
# mean                  NaN                     NaN           NaN
# std                   NaN                     NaN           NaN
# min                   NaN                     NaN           NaN
# 25%                   NaN                     NaN           NaN
# 50%                   NaN                     NaN           NaN
# 75%                   NaN                     NaN           NaN
# max                   NaN                     NaN           NaN

# %%
# Comapring distribuions between Bookings and Cancelations > 180 days
sns.distplot(leadtime_more_180_booked['lead_time'], color='blue', label='Booked')
sns.distplot(leadtime_more_180_cancl['lead_time'], color='red', label='Canceled')
plt.axvline(np.mean(leadtime_more_180_cancl['lead_time']), color='red', linestyle = 'dashed', label='Cancel Mean')
plt.axvline(np.mean(leadtime_more_180_booked['lead_time']), color='blue', linestyle = 'dashed', label='Booked Mean')

plt.legend()
plt.show()

# %%
# Statistics for 'booked' lead time > 180 days
leadtime_more_180_booked['lead_time'].describe()
# Out:
# count    9861.000000
# mean      257.805902
# std        71.039042
# min       180.000000
# 25%       204.000000
# 50%       237.000000
# 75%       292.000000
# max       542.000000
# Name: lead_time, dtype: float64

# %%
# Statistics for 'canceled' lead time > 180 days
leadtime_more_180_cancl['lead_time'].describe()
# Out:
# count    13383.000000
# mean       290.667264
# std         87.852588
# min        180.000000
# 25%        220.000000
# 50%        277.000000
# 75%        332.000000
# max        629.000000
# Name: lead_time, dtype: float64

# %%
# Percentage Difference
(np.mean(leadtime_more_180_cancl['lead_time'])/np.mean(leadtime_more_180_booked['lead_time']) -1)*100
# Out:
# 12.746551627333291

# %% [markdown]
# #### Prepare Data for Analysis | Observations

# %% [markdown]
# - For reservations more than 180 days, the mean lead time for canceled reservations is __12.7%__ greater than booked mean lead time.
# - The data distribution is similar, however, the data is right-skewed = __non-normal distribution__.
#     - Based on intial analysis, is appears that mean lead time for cancellatons are more.
#
#       __NOTE:__ We will confirm this initial observation by running a statistical test.

# %% [markdown]
# ### Check Assumptions

# %% [markdown]
# #### Check Sample Size(s)

# %%
# Sample size?
print(f"Sample Sizes: {len(leadtime_more_180_booked), len(leadtime_more_180_cancl)}")
# Out:
# Sample Sizes: (9861, 13383)

# %% [markdown]
# #### Test for Normality

# %% [markdown]
# #### Visual Normality Checks

# %%
# Comapring distribuions between Bookings and Cancelations > 180 days
sns.distplot(leadtime_more_180_booked['lead_time'], label='Booked')
sns.distplot(leadtime_more_180_cancl['lead_time'], label='Canceled')

plt.legend()
plt.show()

# %% [markdown]
# > Data is right-skewed.

# %% [markdown]
# - The data distribution is similar, however, the data is right-skewed = __non-normal distribution__.

# %%
# Normality Check - Booked?
# Visual Normality Tests: Using Q-Q Plot (Quantile-Quantile Plot)
sm.graphics.qqplot(leadtime_more_180_booked['lead_time'], line='s');

# %%
# Normality Check - Canceled?
# Visual Normality Tests: Using Q-Q Plot (Quantile-Quantile Plot)
sm.graphics.qqplot(leadtime_more_180_cancl['lead_time'], line='s');

# %% [markdown]
# - Q-Q plots show a __non-normal__ distributions as the data points extend away from the red line.

# %% [markdown]
# #### Statistical Normality Checks

# %%
# Normality Check?
# Statistical Normality Tests: Using Shapiro-Wilk Test 
fs.shapiro_test(leadtime_more_180_booked['lead_time'],leadtime_more_180_cancl['lead_time'])
# Out:
# Statistical Normality Tests: Using Shapiro-Wilk Test
# _____
# Statistic: 0.8705, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)
#
# Statistic: 0.906, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)
# C:\Users\deon\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# Normality Check?
# Statistical Normality Tests: Using KS Test
fs.ks_test(leadtime_more_180_booked['lead_time'], "norm")
fs.ks_test(leadtime_more_180_cancl['lead_time'], "norm")
# Out:
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 1.0, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution
#
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 1.0, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution

# %%
# Normality Check?
# Statistical Normality Tests: Using Anderson-Darling Test
from scipy.stats import anderson

result = anderson(leadtime_more_180_cancl['lead_time'])
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        print('%.3f: %.3f, data looks normal ( __Fail to Reject H0__ )' % (sl, cv))
    else:
        print('%.3f: %.3f, data does not look normal ( __Reject H0__ )' % (sl, cv))
# Out:
# Statistic: 266.948
# 15.000: 0.576, data does not look normal ( __Reject H0__ )
# 10.000: 0.656, data does not look normal ( __Reject H0__ )
# 5.000: 0.787, data does not look normal ( __Reject H0__ )
# 2.500: 0.918, data does not look normal ( __Reject H0__ )
# 1.000: 1.092, data does not look normal ( __Reject H0__ )

# %%
# Normality Check?
# Statistical Normality Tests: Using Anderson-Darling Test
fs.anderson_test(leadtime_more_180_booked['lead_time'],leadtime_more_180_cancl['lead_time'])
# Out:
# Statistical Normality Tests: Using Anderson-Darling Test
# _____
#
# Statistic: 363.964
# 15.000: 0.576 __Reject H0__   Data does NOT look normal
# 10.000: 0.656 __Reject H0__   Data does NOT look normal
# 5.000: 0.787 __Reject H0__   Data does NOT look normal
# 2.500: 0.918 __Reject H0__   Data does NOT look normal
# 1.000: 1.092 __Reject H0__   Data does NOT look normal
#
# Statistic: 266.948
# 15.000: 0.576 __Reject H0__   Data does NOT look normal
# 10.000: 0.656 __Reject H0__   Data does NOT look normal
# 5.000: 0.787 __Reject H0__   Data does NOT look normal
# 2.500: 0.918 __Reject H0__   Data does NOT look normal
# 1.000: 1.092 __Reject H0__   Data does NOT look normal

# %%
# Normality Check?
# Statistical Normality Tests: Using D’Agostino’s K^2 Test

from scipy.stats import normaltest

stat, p = normaltest(leadtime_more_180_cancl['lead_time'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
if p > alpha:
    print(f"p-value is {np.round((p), 4)}, __Fail to Reject H0__  Sample looks Gaussian (normal distribution)")
else:
    print(f"p-value is {np.round((p), 4)}, __Reject H0__  Sample does NOT look Gaussian (non-normal distribution)")
# Out:
# Statistics=2681.564, p=0.000
# p-value is 0.0, __Reject H0__  Sample does NOT look Gaussian (non-normal distribution)

# %% [markdown]
# #### Test for Variance
# - The variance criterion holds true when p > a (where a is the probability threshold usually set to 0.05)

# %%
# Variance Check?
# Statistical Variance Tests: Using Levene Variance Test 
fs.levene_test(leadtime_more_180_booked['lead_time'], leadtime_more_180_cancl['lead_time'])
# Out:
# Statistic: 298.5749, P-value: 1.753607252207785e-66,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__     Variances are NOT equal

# %% [markdown]
# #### Observations | Check Assumptions:
# - Plotting sample datasets appear to be right-skewed, suggesting data has a non-normal distribution.
# - Performing several statistical tests for normality, p < 0.05 __failing__ to conform to the normality criterion, therefore __non-normal distribution__.
# - Performing statistical test for variance, p < 0.05 __failing__ to conform to the variance criterion, therefore __variance is unequal__.
# - QQ plot distribution does not confirm to the line, suggesting a __non-normal distribution__.

# %% [markdown]
# ### Perform Statistic Test

# %% [markdown]
# - Normality & Variance criteria: __Both False__
# - Based on above assumptions and observations, we will perform the following:
#
#     - Parametric t-test: __ttest_ind() method by passing the argument equal_var = False__ (Welch's Test)
#     - NOTE: It might be the case that your sample data is large enough to apply parametric t-test although the normality criterion is violated.

# %% [markdown]
# __Two Sample t-test__

# %%
# Calculate t-statistic for samples, using Two-Sample T-test (independent)
# In case of unequal variances a better option is to call the ttest_ind() method by passing the argument equal_var = False

stat, p = stats.ttest_ind(leadtime_more_180_booked['lead_time'], leadtime_more_180_cancl['lead_time'], equal_var = False)
print(f"Statistic for sample is {round(stat, 4)} and the p-value is {p}: Rounded the p-value is {np.round((p), 4)}")

if p <= alpha:
    print(f"p-value is {np.round((p), 4)},  Reject the Null hypothesis")
else:
    print(f"p-value is {np.round((p), 4)},  Fail to reject the Null hypothesis")
# Out:
# Statistic for sample is -31.4975 and the p-value is 3.09554284823593e-213: Rounded the p-value is 0.0
# p-value is 0.0,  Reject the Null hypothesis

# %% [markdown]
# __Welch's t-test__

# %%
# Calculate statistic for samples, using Welch's T-test which is maintained in the flatirons.py file
p = fs.p_value_welch_ttest(leadtime_more_180_booked['lead_time'], leadtime_more_180_cancl['lead_time'], two_sided=True)
print(f"The p-value is {p}: Rounded the p-value is {np.round((p), 4)}")

if p <= alpha:
    print(f"p-value is {np.round((p), 4)} - Reject the Null hypothesis")
else:
    print(f"p-value is {np.round((p), 4)} - Fail to reject the Null hypothesis")
# Out:
# The p-value is 0.0: Rounded the p-value is 0.0
# p-value is 0.0 - Reject the Null hypothesis

# %% [markdown]
# #### Observations | Perform Statistic Test :
# - Since p < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that booking 180 days in advance does have a statistical significant effect on the number of cancellations.

# %% [markdown]
# ### Perform Effect Size (Cohen's d) Test

# %% [markdown]
# > __Define Cohen'd Test?__

# %%
# Calculate effect size for samples, using Cohen's (D) used to indicate the standardised difference between two means.
cohens_d_results = fs.cohens_d(leadtime_more_180_booked['lead_time'], leadtime_more_180_cancl['lead_time'])
print(f"The effect size (d) is {cohens_d_results}: Rounded (d) is {np.round((cohens_d_results), 4)}")
# Out:
# The effect size (d) is -0.4049647480696389: Rounded (d) is -0.405

# %% [markdown]
# #### Perform Effect Size | Observation:
# -  Cohen's D, how to interpret results:
#
#     - d=0.2 be considered a 'small' effect size
#
#     - d=0.5 represents a 'medium' effect size
#
#     - d=0.8 a 'large' effect size.

# %% [markdown]
# > __0.405__, is a medium effect size according to chart above.

# %%
print(f"Sample Sizes: {len(leadtime_more_180_booked['lead_time']), len(leadtime_more_180_cancl['lead_time'])}")
# Out:
# Sample Sizes: (9861, 13383)

# %%
#Calculate sample size required
from statsmodels.stats.power import TTestIndPower, TTestPower
power_analysis = TTestIndPower()
power_analysis.solve_power(effect_size=-0.405, alpha=.05, power=.8)
# Out:
# 96.67302419483546

# %%
#Calculate minimum effect size to satisfy desired alpha and power as well as respect sample size limitations
power_analysis.solve_power(nobs1=96.6730, alpha=.05, power=.8)
# Out:
# 0.40500004550159924

# %% [markdown]
# ### __Conclusions: 2- Data Analysis__
# - __p-value:__ Rounded the p-value is 0.0
# - __effect size:__ d=__0.405__, is a __medium effect size__
# - __Observations:__ Since p-value is 0.0 < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that lead time has a statistical significant effect on cancellations."

# %% [markdown]
# ## __3- Data Analysis - Lead time > 365 days__

# %% [markdown]
# ### Prepare Data for Analysis

# %%
leadtime_more_365_booked = df[(df['lead_time'] >= 365) & (df['is_canceled']==0)]
leadtime_more_365_booked[:10]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 203   Resort Hotel            0        394               2015
# 222   Resort Hotel            0        366               2015
# 802   Resort Hotel            0        460               2015
# 1349  Resort Hotel            0        381               2015
# 1484  Resort Hotel            0        382               2015
# 5797  Resort Hotel            0        424               2016
# 6540  Resort Hotel            0        367               2016
# 6541  Resort Hotel            0        367               2016
# 6618  Resort Hotel            0        373               2016
# 6639  Resort Hotel            0        374               2016
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 203                July                        28                          8
# 222                July                        28                          9
# 802              August                        32                          3
# 1349          September                        36                          1
# 1484          September                        37                          8
# 5797               July                        29                         11
# 6540             August                        35                         21
# 6541             August                        35                         21
# 6618             August                        35                         26
# 6639             August                        35                         27
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 203                         2                     5       2       0.0       0
# 222                         2                     5       2       0.0       0
# 802                         2                     5       1       0.0       0
# 1349                        4                    10       2       0.0       0
# 1484                        4                    10       2       0.0       0
# 5797                        3                     7       2       1.0       0
# 6540                        4                    10       2       0.0       0
# 6541                        4                    10       2       0.0       0
# 6618                        3                     7       2       0.0       0
# 6639                        4                    10       2       0.0       0
#
#      meal country market_segment distribution_channel  is_repeated_guest  \
# 203    HB     GBR  Offline TA/TO                TA/TO                  0
# 222    HB     GBR  Offline TA/TO                TA/TO                  0
# 802    HB     GBR  Offline TA/TO                TA/TO                  0
# 1349   BB     GBR  Offline TA/TO                TA/TO                  0
# 1484   BB     GBR  Offline TA/TO                TA/TO                  0
# 5797   BB     GBR  Offline TA/TO                TA/TO                  0
# 6540   BB     GBR  Offline TA/TO                TA/TO                  0
# 6541   BB     GBR  Offline TA/TO                TA/TO                  0
# 6618   BB     GBR  Offline TA/TO                TA/TO                  0
# 6639   BB     GBR  Offline TA/TO                TA/TO                  0
#
#       previous_cancellations  previous_bookings_not_canceled  \
# 203                        0                               0
# 222                        0                               0
# 802                        0                               0
# 1349                       0                               0
# 1484                       0                               0
# 5797                       0                               0
# 6540                       0                               0
# 6541                       0                               0
# 6618                       0                               0
# 6639                       0                               0
#
#      reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 203                   D                  D                0   No Deposit
# 222                   E                  E                0   No Deposit
# 802                   E                  E                0   No Deposit
# 1349                  E                  E                0   No Deposit
# 1484                  E                  E                0   No Deposit
# 5797                  E                  E                0   No Deposit
# 6540                  D                  D                0   No Deposit
# 6541                  A                  A                0   No Deposit
# 6618                  E                  E                0   No Deposit
# 6639                  E                  E                0   No Deposit
#
#       agent  days_in_waiting_list customer_type     adr  \
# 203    40.0                     0      Contract   89.68
# 222    40.0                     0      Contract  134.73
# 802    40.0                     0      Contract   77.54
# 1349   40.0                     0      Contract   82.88
# 1484   40.0                     0      Contract   76.50
# 5797   40.0                     0     Transient  112.63
# 6540    2.0                     0     Transient   70.00
# 6541    2.0                     0      Contract   57.80
# 6618   40.0                     0      Contract   85.30
# 6639   40.0                     0      Contract   85.30
#
#       required_car_parking_spaces  total_of_special_requests  \
# 203                             0                          0
# 222                             0                          0
# 802                             0                          0
# 1349                            0                          0
# 1484                            0                          0
# 5797                            0                          1
# 6540                            0                          1
# 6541                            0                          1
# 6618                            0                          0
# 6639                            0                          0
#
#      reservation_status reservation_status_date leadTime_catg
# 203           Check-Out                  201507    (365, 765]
# 222           Check-Out                  201507    (365, 765]
# 802           Check-Out                  201508    (365, 765]
# 1349          Check-Out                  201509    (365, 765]
# 1484          Check-Out                  201509    (365, 765]
# 5797          Check-Out                  201607    (365, 765]
# 6540          Check-Out                  201609    (365, 765]
# 6541          Check-Out                  201609    (365, 765]
# 6618          Check-Out                  201609    (365, 765]
# 6639          Check-Out                  201609    (365, 765]

# %%
leadtime_more_365_cancl = df[(df['lead_time'] >= 365) & (df['is_canceled']==1)]
leadtime_more_365_cancl[:10]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 70    Resort Hotel            1        368               2015
# 2112  Resort Hotel            1        368               2015
# 4802  Resort Hotel            1        468               2016
# 4803  Resort Hotel            1        468               2016
# 4805  Resort Hotel            1        468               2016
# 4806  Resort Hotel            1        468               2016
# 4809  Resort Hotel            1        468               2016
# 4810  Resort Hotel            1        468               2016
# 4811  Resort Hotel            1        468               2016
# 4812  Resort Hotel            1        468               2016
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 70                 July                        27                          3
# 2112            October                        41                         10
# 4802                May                        20                         12
# 4803                May                        20                         12
# 4805                May                        20                         12
# 4806                May                        20                         12
# 4809                May                        20                         12
# 4810                May                        20                         12
# 4811                May                        20                         12
# 4812                May                        20                         12
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 70                          3                     7       2       0.0       0
# 2112                        2                     5       1       0.0       0
# 4802                        0                     2       2       0.0       0
# 4803                        0                     2       2       0.0       0
# 4805                        0                     2       2       0.0       0
# 4806                        0                     2       2       0.0       0
# 4809                        0                     2       2       0.0       0
# 4810                        0                     2       2       0.0       0
# 4811                        0                     2       2       0.0       0
# 4812                        0                     2       2       0.0       0
#
#      meal country market_segment distribution_channel  is_repeated_guest  \
# 70     BB     PRT  Offline TA/TO                TA/TO                  0
# 2112   BB     PRT  Offline TA/TO                TA/TO                  0
# 4802   HB     PRT         Groups                TA/TO                  0
# 4803   HB     PRT         Groups                TA/TO                  0
# 4805   HB     PRT         Groups                TA/TO                  0
# 4806   HB     PRT         Groups                TA/TO                  0
# 4809   HB     PRT         Groups                TA/TO                  0
# 4810   HB     PRT         Groups                TA/TO                  0
# 4811   HB     PRT         Groups                TA/TO                  0
# 4812   HB     PRT         Groups                TA/TO                  0
#
#       previous_cancellations  previous_bookings_not_canceled  \
# 70                         0                               0
# 2112                       0                               0
# 4802                       0                               0
# 4803                       0                               0
# 4805                       0                               0
# 4806                       0                               0
# 4809                       0                               0
# 4810                       0                               0
# 4811                       0                               0
# 4812                       0                               0
#
#      reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 70                    A                  A                0   No Deposit
# 2112                  A                  A                0   No Deposit
# 4802                  A                  A                0   No Deposit
# 4803                  A                  A                0   No Deposit
# 4805                  A                  A                0   No Deposit
# 4806                  A                  A                0   No Deposit
# 4809                  A                  A                0   No Deposit
# 4810                  A                  A                1   No Deposit
# 4811                  A                  A                0   No Deposit
# 4812                  A                  A                0   No Deposit
#
#       agent  days_in_waiting_list    customer_type    adr  \
# 70     40.0                     0         Contract  55.68
# 2112   96.0                     0        Transient   4.00
# 4802  249.0                     0  Transient-Party  67.00
# 4803  249.0                     0  Transient-Party  67.00
# 4805  249.0                     0  Transient-Party  67.00
# 4806  249.0                     0  Transient-Party  67.00
# 4809  249.0                     0  Transient-Party  67.00
# 4810  249.0                     0  Transient-Party  26.00
# 4811  249.0                     0  Transient-Party  67.00
# 4812  249.0                     0  Transient-Party  67.00
#
#       required_car_parking_spaces  total_of_special_requests  \
# 70                              0                          0
# 2112                            0                          0
# 4802                            0                          0
# 4803                            0                          0
# 4805                            0                          0
# 4806                            0                          0
# 4809                            0                          0
# 4810                            0                          0
# 4811                            0                          0
# 4812                            0                          0
#
#      reservation_status reservation_status_date leadTime_catg
# 70             Canceled                  201505    (365, 765]
# 2112           Canceled                  201505    (365, 765]
# 4802           Canceled                  201603    (365, 765]
# 4803           Canceled                  201603    (365, 765]
# 4805           Canceled                  201603    (365, 765]
# 4806           Canceled                  201603    (365, 765]
# 4809           Canceled                  201603    (365, 765]
# 4810           Canceled                  201605    (365, 765]
# 4811           Canceled                  201603    (365, 765]
# 4812           Canceled                  201603    (365, 765]

# %%
# Comapring distribuions between Bookings and Cancelations > 180 days
sns.distplot(leadtime_more_365_booked['lead_time'], color='blue', label='Booked')
sns.distplot(leadtime_more_365_cancl['lead_time'], color='red', label='Canceled')
plt.axvline(np.mean(leadtime_more_365_cancl['lead_time']), color='red', linestyle = 'dashed', label='Cancel Mean')
plt.axvline(np.mean(leadtime_more_365_booked['lead_time']), color='blue', linestyle = 'dashed', label='Booked Mean')

plt.legend()
plt.show()

# %%
leadtime_more_365_booked['lead_time'].describe()
# Out:
# count    950.000000
# mean     423.391579
# std       40.575579
# min      365.000000
# 25%      394.000000
# 50%      414.000000
# 75%      457.000000
# max      542.000000
# Name: lead_time, dtype: float64

# %%
leadtime_more_365_cancl['lead_time'].describe()
# Out:
# count    2103.000000
# mean      448.747979
# std        70.058703
# min       365.000000
# 25%       393.000000
# 50%       433.000000
# 75%       475.000000
# max       629.000000
# Name: lead_time, dtype: float64

# %%
# Percentage Difference
(np.mean(leadtime_more_365_cancl['lead_time'])/np.mean(leadtime_more_365_booked['lead_time']) -1)*100
# Out:
# 5.988876820172173

# %% [markdown]
# #### Prepare Data for Analysis | Observations

# %% [markdown]
# - For reservations more than 365 days, the mean lead time for canceled reservations is greater = __5.9%__
# - The data distribution is similar, however, the data is right-skewed = __non-normal distribution__.
#     - Based on intial analysis, is appears that lead time for cancellations is more.
#
#       __NOTE:__ We will confirm this initial observation by running a statistical test.

# %% [markdown]
# ### Check Assumptions

# %% [markdown]
# #### Visual Normality Check

# %%
# Normality Check?
sns.distplot(leadtime_more_365_booked['lead_time'], label='Booked more than 365 days' )
sns.distplot(leadtime_more_365_cancl['lead_time'], label='Canceled more than 365 days')
plt.legend()
plt.show()

# %% [markdown]
# __Statistical Normality Checks__

# %%
# Normality Check?
# Statistical Normality Tests: Using Shapiro-Wilk Test 

# In the SciPy implementation of these tests, you can interpret the p value as follows:
#     p <= alpha: reject H0, not normal.
#     p > alpha: fail to reject H0, normal.

fs.shapiro_test(leadtime_more_365_booked['lead_time'],leadtime_more_365_cancl['lead_time'])
# Out:
# Statistical Normality Tests: Using Shapiro-Wilk Test
# _____
# Statistic: 0.9074, P-value: 1.4654247784567348e-23,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)
#
# Statistic: 0.8833, P-value: 3.7581925740096883e-37,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample does NOT look Gaussian (non-normal distribution)

# %%
# Normality Check?
# Statistical Normality Tests: Using KS Test

fs.ks_test(leadtime_more_365_booked['lead_time'], "norm")
fs.ks_test(leadtime_more_365_cancl['lead_time'], "norm")
# Out:
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 1.0, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution
#
# Statistical Normality Tests: Using K-S Test
# _____
# Statistic: 1.0, P-value: 0.0,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__          Sample distribution is NOT identical to a normal distribution

# %% [markdown]
# __Test for Variance__
# - The variance criterion holds true when p > a (where a is the probability threshold usually set to 0.05)

# %%
# Variance Check?
# Statistical Variance Tests: Using Levene Variance Test 
fs.levene_test(leadtime_more_365_booked['lead_time'], leadtime_more_365_cancl['lead_time'])
# Out:
# Statistic: 169.7108, P-value: 8.560769818598236e-38,  Rounded P-value: 0.0
# Test Conclusion: __Reject H0__     Variances are NOT equal

# %% [markdown]
# #### Observations | Check Assumptions:
# - Plotting sample datasets appear to be right-skewed, suggesting data has a non-normal distribution.
# - Performing several statistical tests for normality, p < 0.05 __failing__ to conform to the normality criterion, therefore __non-normal distribution__.
# - Performing statistical test for variance, p < 0.05 __failing__ to conform to the variance criterion, therefore __variance is unequal__.
# - QQ plot distribution does not confirm to the line, suggesting a __non-normal distribution__.

# %% [markdown]
# ### Perform Statistic Test

# %% [markdown]
# __Welch's t-test__

# %%
# Calculate statistic for samples, using Welch's T-test which is maintained in the flatirons.py file
p = fs.p_value_welch_ttest(leadtime_more_365_booked['lead_time'], leadtime_more_365_cancl['lead_time'], two_sided=True)
print(f"The p-value is {p}: Rounded the p-value is {np.round((p), 4)}")

if p <= alpha:
    print(f"p-value is {np.round((p), 4)} - Reject the Null hypothesis")
else:
    print(f"p-value is {np.round((p), 4)} - Fail to reject the Null hypothesis")
# Out:
# The p-value is 0.0: Rounded the p-value is 0.0
# p-value is 0.0 - Reject the Null hypothesis

# %% [markdown]
# ### Perform Effect Size (Cohen's d) Test

# %%
# Calculate effect size for samples, using Cohen's (D) used to indicate the standardised difference between two means.
cohens_d_results = fs.cohens_d(leadtime_more_365_booked['lead_time'], leadtime_more_365_cancl['lead_time'])
print(f"The effect size (d) is {cohens_d_results}: Rounded (d) is {np.round((cohens_d_results), 4)}")
# Out:
# The effect size (d) is -0.4063799137652514: Rounded (d) is -0.4064

# %% [markdown]
# __Perform Effect Size | Observation:__
# -  Cohen's D, how to interpret results:
#
#     - d=0.2 be considered a 'small' effect size
#
#     - d=0.5 represents a 'medium' effect size
#
#     - d=0.8 a 'large' effect size.

# %% [markdown]
# > __0.4064__, is a medium effect size according to chart above.

# %%
#Calculate sample size required
from statsmodels.stats.power import TTestIndPower, TTestPower
power_analysis = TTestIndPower()
power_analysis.solve_power(effect_size=-0.4064, alpha=.05, power=.8)
# Out:
# 96.0148528048343

# %% [markdown]
# ### __Conclusions: 3- Data Analysis__
# - __p-value:__ Rounded the p-value is 0.0
# - __effect size:__ d=__0.4064__, is a __medium effect size__
# - __Observations:__ Since p-value is 0.0 < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that lead time has a statistical significant effect on cancellations."

# %% [markdown]
# ## __Hypothesis Test 1 - Conclusions:__
# - __p-value:__ Rounded p-value is __0.0__ for all analysis performed on lead time for all reservations, and reservations made greater than 180 days and 365 days.
# - __Observations:__ Since p-value is __0.0__ < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that lead time has a statistical significant effect on cancellations." Since the mean of the cancellation sample is bigger than the booked sample the conclusion is that booking far in advance increases the probability of cancellation.

# %% [markdown]
# # __Hypothesis Test 2: Which specific Lead Time Categories have an effect on cancellations?__

# %% [markdown]
# - Based on __Hypothesis Test 1 - Conclusions__, which indicates that cancellations are effected by lead time, we would like to know which specific lead time categories have the most significant effect. In other words our null hypothesis is that the means of all populations are equal.  Rejecting the null hypothesis would mean that there is a significant difference between at least two of the lead time categories.
#
# - The decision to reject the null hypothesis and accept the alternative hypothesis is based on the significance level of the test (alpha) and the probability of observing the effect given that the null hypothesis is true (p-value). If p < alpha the null hypothesis is ruled out. We typically use a value of alpha = 0.05, which corresponds to 95% confidence.

# %% [markdown]
# ## State Hypothesis:
# - $H_{0}$: The null hypothesis is that lead time categories do __not__ have an effect on cancellations.
#
#   $H_{0}: \mu1 = \mu2$
#
#
# - $H_{1}$: The alternative hypothesis is that lead time categories __do__ have an effect on cancellations.
#
#   $H_{1}: \mu1 ≠ \mu2$
#
#
# - __α__:   The significance level, also denoted as alpha or α, is the probability of rejecting the null hypothesis when it is true.
#
#   __α__ = 0.05 or 5%

# %% [markdown]
# ## Anova Test (One-way)

# %% [markdown]
# ### Prepare data for analysis

# %%
# Prepare dataset for evaluation
df_cancl = df.loc[df['is_canceled']==1]
df_cancl = df_cancl.dropna()
display(df_cancl.head(), df_cancl.shape)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 4   Resort Hotel            1         85               2015
# 5   Resort Hotel            1         75               2015
# 6   Resort Hotel            1         23               2015
# 22  Resort Hotel            1         60               2015
# 27  Resort Hotel            1         45               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 4                July                        27                          1
# 5                July                        27                          1
# 6                July                        27                          1
# 22               July                        27                          1
# 27               July                        27                          2
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 4                         0                     3       2       0.0       0
# 5                         0                     3       2       0.0       0
# 6                         0                     4       2       0.0       0
# 22                        2                     5       2       0.0       0
# 27                        1                     3       3       0.0       0
#
#    meal country market_segment distribution_channel  is_repeated_guest  \
# 4    BB     PRT      Online TA                TA/TO                  0
# 5    HB     PRT  Offline TA/TO                TA/TO                  0
# 6    BB     PRT      Online TA                TA/TO                  0
# 22   BB     PRT      Online TA                TA/TO                  0
# 27   BB     PRT      Online TA                TA/TO                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 4                        0                               0                  A
# 5                        0                               0                  D
# 6                        0                               0                  E
# 22                       0                               0                  E
# 27                       0                               0                  D
#
#    assigned_room_type  booking_changes deposit_type  agent  \
# 4                   A                0   No Deposit  240.0
# 5                   D                0   No Deposit   15.0
# 6                   E                0   No Deposit  240.0
# 22                  E                0   No Deposit  240.0
# 27                  D                0   No Deposit  241.0
#
#     days_in_waiting_list customer_type    adr  required_car_parking_spaces  \
# 4                      0     Transient   82.0                            0
# 5                      0     Transient  105.5                            0
# 6                      0     Transient  123.0                            0
# 22                     0     Transient  107.0                            0
# 27                     0     Transient  108.8                            0
#
#     total_of_special_requests reservation_status reservation_status_date  \
# 4                           1           Canceled                  201505
# 5                           0           Canceled                  201504
# 6                           0           Canceled                  201506
# 22                          2           Canceled                  201505
# 27                          1           Canceled                  201505
#
#    leadTime_catg
# 4       (60, 90]
# 5       (60, 90]
# 6       (21, 30]
# 22      (45, 60]
# 27      (30, 45]
# (39939, 32)

# %%
# Preview leadTime Categories
df_cancl_grp = df_cancl.groupby(by='leadTime_catg').count().reset_index()
df_cancl_grp
# Out:
#    leadTime_catg  hotel  is_canceled  lead_time  arrival_date_year  \
# 0         (0, 6]    891          891        891                891
# 1         (6, 7]    128          128        128                128
# 2        (7, 14]   1331         1331       1331               1331
# 3       (14, 21]   1489         1489       1489               1489
# 4       (21, 30]   1845         1845       1845               1845
# 5       (30, 45]   3081         3081       3081               3081
# 6       (45, 60]   2547         2547       2547               2547
# 7       (60, 90]   4637         4637       4637               4637
# 8      (90, 120]   4150         4150       4150               4150
# 9     (120, 180]   6568         6568       6568               6568
# 10    (180, 270]   6024         6024       6024               6024
# 11    (270, 300]   1978         1978       1978               1978
# 12    (300, 365]   3220         3220       3220               3220
# 13    (365, 765]   2050         2050       2050               2050
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                  891                       891                        891
# 1                  128                       128                        128
# 2                 1331                      1331                       1331
# 3                 1489                      1489                       1489
# 4                 1845                      1845                       1845
# 5                 3081                      3081                       3081
# 6                 2547                      2547                       2547
# 7                 4637                      4637                       4637
# 8                 4150                      4150                       4150
# 9                 6568                      6568                       6568
# 10                6024                      6024                       6024
# 11                1978                      1978                       1978
# 12                3220                      3220                       3220
# 13                2050                      2050                       2050
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                       891                   891     891       891     891
# 1                       128                   128     128       128     128
# 2                      1331                  1331    1331      1331    1331
# 3                      1489                  1489    1489      1489    1489
# 4                      1845                  1845    1845      1845    1845
# 5                      3081                  3081    3081      3081    3081
# 6                      2547                  2547    2547      2547    2547
# 7                      4637                  4637    4637      4637    4637
# 8                      4150                  4150    4150      4150    4150
# 9                      6568                  6568    6568      6568    6568
# 10                     6024                  6024    6024      6024    6024
# 11                     1978                  1978    1978      1978    1978
# 12                     3220                  3220    3220      3220    3220
# 13                     2050                  2050    2050      2050    2050
#
#     meal  country  market_segment  distribution_channel  is_repeated_guest  \
# 0    891      891             891                   891                891
# 1    128      128             128                   128                128
# 2   1331     1331            1331                  1331               1331
# 3   1489     1489            1489                  1489               1489
# 4   1845     1845            1845                  1845               1845
# 5   3081     3081            3081                  3081               3081
# 6   2547     2547            2547                  2547               2547
# 7   4637     4637            4637                  4637               4637
# 8   4150     4150            4150                  4150               4150
# 9   6568     6568            6568                  6568               6568
# 10  6024     6024            6024                  6024               6024
# 11  1978     1978            1978                  1978               1978
# 12  3220     3220            3220                  3220               3220
# 13  2050     2050            2050                  2050               2050
#
#     previous_cancellations  previous_bookings_not_canceled  \
# 0                      891                             891
# 1                      128                             128
# 2                     1331                            1331
# 3                     1489                            1489
# 4                     1845                            1845
# 5                     3081                            3081
# 6                     2547                            2547
# 7                     4637                            4637
# 8                     4150                            4150
# 9                     6568                            6568
# 10                    6024                            6024
# 11                    1978                            1978
# 12                    3220                            3220
# 13                    2050                            2050
#
#     reserved_room_type  assigned_room_type  booking_changes  deposit_type  \
# 0                  891                 891              891           891
# 1                  128                 128              128           128
# 2                 1331                1331             1331          1331
# 3                 1489                1489             1489          1489
# 4                 1845                1845             1845          1845
# 5                 3081                3081             3081          3081
# 6                 2547                2547             2547          2547
# 7                 4637                4637             4637          4637
# 8                 4150                4150             4150          4150
# 9                 6568                6568             6568          6568
# 10                6024                6024             6024          6024
# 11                1978                1978             1978          1978
# 12                3220                3220             3220          3220
# 13                2050                2050             2050          2050
#
#     agent  days_in_waiting_list  customer_type   adr  \
# 0     891                   891            891   891
# 1     128                   128            128   128
# 2    1331                  1331           1331  1331
# 3    1489                  1489           1489  1489
# 4    1845                  1845           1845  1845
# 5    3081                  3081           3081  3081
# 6    2547                  2547           2547  2547
# 7    4637                  4637           4637  4637
# 8    4150                  4150           4150  4150
# 9    6568                  6568           6568  6568
# 10   6024                  6024           6024  6024
# 11   1978                  1978           1978  1978
# 12   3220                  3220           3220  3220
# 13   2050                  2050           2050  2050
#
#     required_car_parking_spaces  total_of_special_requests  \
# 0                           891                        891
# 1                           128                        128
# 2                          1331                       1331
# 3                          1489                       1489
# 4                          1845                       1845
# 5                          3081                       3081
# 6                          2547                       2547
# 7                          4637                       4637
# 8                          4150                       4150
# 9                          6568                       6568
# 10                         6024                       6024
# 11                         1978                       1978
# 12                         3220                       3220
# 13                         2050                       2050
#
#     reservation_status  reservation_status_date
# 0                  891                      891
# 1                  128                      128
# 2                 1331                     1331
# 3                 1489                     1489
# 4                 1845                     1845
# 5                 3081                     3081
# 6                 2547                     2547
# 7                 4637                     4637
# 8                 4150                     4150
# 9                 6568                     6568
# 10                6024                     6024
# 11                1978                     1978
# 12                3220                     3220
# 13                2050                     2050

# %%
df_cancl['leadTime_catg'] = df_cancl['leadTime_catg'].astype(str)

# %% [markdown]
# ### Perform One-way Anova Test

# %% [markdown]
# > One-way ANOVA and returns the F and p values from the test.

# %%
# ANOVA Test: Lead Time Category
formula = 'lead_time ~ C(leadTime_catg)'
lm = ols(formula, df_cancl).fit()
table = sm.stats.anova_lm(lm, typ=2)
table
# Out:
#                         sum_sq       df             F  PR(>F)
# C(leadTime_catg)  5.514377e+08     13.0  92431.792397     0.0
# Residual          1.832216e+07  39925.0           NaN     NaN

# %% [markdown]
# - As 0.00 < 0.05 we reject the null hypothesis and we conclude that at least one of the means is different from at least one other population mean (i.e. not all leadTime categories perform equally).

# %% [markdown]
# ## Perform Tukey Analysis

# %% [markdown]
# > The thing with one-way ANOVA is that although we now know that there is difference in the lead time categories, we do not know know exactly which category performed best or worst with the cancellations. This is why the analysis of variance is often followed by a post hoc analysis.
# - This a common method used as post hoc analysis after one-way ANOVA. This test compares all possible pairs and we can use it to precisely identify difference between two means that's greater than the expected standard error.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

mc = MultiComparison(df_cancl['lead_time'], df_cancl['leadTime_catg'])
result = mc.tukeyhsd()
 
print(result)
print(mc.groupsunique)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#   group1     group2    meandiff p-adj    lower     upper   reject
# -----------------------------------------------------------------
#     (0, 6] (120, 180]  147.3338  0.001  144.7687  149.8989   True
#     (0, 6]   (14, 21]   14.4319  0.001   11.3888   17.4751   True
#     (0, 6] (180, 270]  217.4358  0.001  214.8569  220.0147   True
#     (0, 6]   (21, 30]   22.7078  0.001   19.7766    25.639   True
#     (0, 6] (270, 300]  280.2086  0.001  277.3097  283.1075   True
#     (0, 6]   (30, 45]    34.255  0.001    31.522   36.9881   True
#     (0, 6] (300, 365]   323.826  0.001  321.1062  326.5458   True
#     (0, 6] (365, 765]  447.4519  0.001  444.5688   450.335   True
#     (0, 6]   (45, 60]   49.9042  0.001   47.1077   52.7008   True
#     (0, 6]     (6, 7]    3.5387    0.9   -3.2528   10.3302  False
#     (0, 6]   (60, 90]   71.5003  0.001   68.8722   74.1285   True
#     (0, 6]    (7, 14]    7.5635  0.001    4.4535   10.6736   True
#     (0, 6]  (90, 120]  101.2633  0.001   98.6104  103.9162   True
# (120, 180]   (14, 21] -132.9019  0.001 -134.9641 -130.8396   True
# (120, 180] (180, 270]    70.102  0.001   68.8202   71.3838   True
# (120, 180]   (21, 30]  -124.626  0.001 -126.5191 -122.7328   True
# (120, 180] (270, 300]  132.8748  0.001   131.032  134.7176   True
# (120, 180]   (30, 45] -113.0787  0.001 -114.6477 -111.5098   True
# (120, 180] (300, 365]  176.4922  0.001  174.9465  178.0379   True
# (120, 180] (365, 765]  300.1181  0.001  298.3004  301.9359   True
# (120, 180]   (45, 60]  -97.4295  0.001  -99.1067  -95.7524   True
# (120, 180]     (6, 7] -143.7951  0.001 -150.2073 -137.3828   True
# (120, 180]   (60, 90]  -75.8335  0.001  -77.2116  -74.4553   True
# (120, 180]    (7, 14] -139.7703  0.001   -141.93 -137.6105   True
# (120, 180]  (90, 120]  -46.0705  0.001  -47.4952  -44.6457   True
#   (14, 21] (180, 270]  203.0039  0.001  200.9244  205.0833   True
#   (14, 21]   (21, 30]    8.2759  0.001    5.7729   10.7789   True
#   (14, 21] (270, 300]  265.7767  0.001  263.3115  268.2418   True
#   (14, 21]   (30, 45]   19.8231  0.001   17.5554   22.0908   True
#   (14, 21] (300, 365]  309.3941  0.001  307.1423  311.6458   True
#   (14, 21] (365, 765]    433.02  0.001  430.5735  435.4664   True
#   (14, 21]   (45, 60]   35.4723  0.001   33.1284   37.8162   True
#   (14, 21]     (6, 7]  -10.8932  0.001  -17.5112   -4.2752   True
#   (14, 21]   (60, 90]   57.0684  0.001   54.9282   59.2086   True
#   (14, 21]    (7, 14]   -6.8684  0.001   -9.5787   -4.1582   True
#   (14, 21]  (90, 120]   86.8314  0.001   84.6609   89.0018   True
# (180, 270]   (21, 30]  -194.728  0.001 -196.6398 -192.8162   True
# (180, 270] (270, 300]   62.7728  0.001   60.9108   64.6347   True
# (180, 270]   (30, 45] -183.1808  0.001 -184.7721 -181.5894   True
# (180, 270] (300, 365]  106.3902  0.001  104.8217  107.9587   True
# (180, 270] (365, 765]  230.0161  0.001  228.1789  231.8533   True
# (180, 270]   (45, 60] -167.5316  0.001 -169.2297 -165.8334   True
# (180, 270]     (6, 7] -213.8971  0.001 -220.3149 -207.4793   True
# (180, 270]   (60, 90] -145.9355  0.001 -147.3391 -144.5318   True
# (180, 270]    (7, 14] -209.8723  0.001 -212.0484 -207.6962   True
# (180, 270]  (90, 120] -116.1725  0.001  -117.622  -114.723   True
#   (21, 30] (270, 300]  257.5008  0.001  255.1753  259.8263   True
#   (21, 30]   (30, 45]   11.5472  0.001    9.4321   13.6623   True
#   (21, 30] (300, 365]  301.1182  0.001  299.0202  303.2161   True
#   (21, 30] (365, 765]  424.7441  0.001  422.4384  427.0498   True
#   (21, 30]   (45, 60]   27.1964  0.001   24.9999    29.393   True
#   (21, 30]     (6, 7]  -19.1691  0.001  -25.7364  -12.6018   True
#   (21, 30]   (60, 90]   48.7925  0.001   46.8148   50.7702   True
#   (21, 30]    (7, 14]  -15.1443  0.001  -17.7282  -12.5604   True
#   (21, 30]  (90, 120]   78.5555  0.001    76.545   80.5659   True
# (270, 300]   (30, 45] -245.9535  0.001 -248.0237 -243.8834   True
# (270, 300] (300, 365]   43.6174  0.001   41.5648     45.67   True
# (270, 300] (365, 765]  167.2433  0.001  164.9788  169.5078   True
# (270, 300]   (45, 60] -230.3043  0.001 -232.4576  -228.151   True
# (270, 300]     (6, 7] -276.6699  0.001 -283.2228 -270.1169   True
# (270, 300]   (60, 90] -208.7083  0.001 -210.6378 -206.7787   True
# (270, 300]    (7, 14] -272.6451  0.001 -275.1923 -270.0978   True
# (270, 300]  (90, 120] -178.9453  0.001 -180.9084 -176.9822   True
#   (30, 45] (300, 365]  289.5709  0.001  287.7602  291.3817   True
#   (30, 45] (365, 765]  413.1968  0.001   411.149  415.2447   True
#   (30, 45]   (45, 60]   15.6492  0.001    13.725   17.5734   True
#   (30, 45]     (6, 7]  -30.7163  0.001  -37.1976  -24.2351   True
#   (30, 45]   (60, 90]   37.2453  0.001   35.5753   38.9153   True
#   (30, 45]    (7, 14]  -26.6915  0.001  -29.0482  -24.3348   True
#   (30, 45]  (90, 120]   67.0083  0.001   65.2996   68.7169   True
# (300, 365] (365, 765]  123.6259  0.001  121.5958   125.656   True
# (300, 365]   (45, 60] -273.9217  0.001  -275.827 -272.0165   True
# (300, 365]     (6, 7] -320.2873  0.001 -326.7629 -313.8116   True
# (300, 365]   (60, 90] -252.3257  0.001 -253.9738 -250.6775   True
# (300, 365]    (7, 14] -316.2625  0.001 -318.6038 -313.9212   True
# (300, 365]  (90, 120] -222.5627  0.001   -224.25 -220.8753   True
# (365, 765]   (45, 60] -397.5476  0.001 -399.6796 -395.4157   True
# (365, 765]     (6, 7] -443.9132  0.001 -450.4591 -437.3672   True
# (365, 765]   (60, 90] -375.9516  0.001 -377.8572 -374.0459   True
# (365, 765]    (7, 14] -439.8884  0.001 -442.4176 -437.3592   True
# (365, 765]  (90, 120] -346.1886  0.001 -348.1282  -344.249   True
#   (45, 60]     (6, 7]  -46.3655  0.001  -52.8738  -39.8572   True
#   (45, 60]   (60, 90]   21.5961  0.001    19.824   23.3681   True
#   (45, 60]    (7, 14]  -42.3407  0.001  -44.7708  -39.9106   True
#   (45, 60]  (90, 120]   51.3591  0.001   49.5505   53.1676   True
#     (6, 7]   (60, 90]   67.9616  0.001   61.5239   74.3993   True
#     (6, 7]    (7, 14]    4.0248 0.7194   -2.6242   10.6738  False
#     (6, 7]  (90, 120]   97.7246  0.001   91.2767  104.1724   True
#   (60, 90]    (7, 14]  -63.9368  0.001  -66.1711  -61.7026   True
#   (60, 90]  (90, 120]    29.763  0.001   28.2276   31.2983   True
#    (7, 14]  (90, 120]   93.6998  0.001   91.4365   95.9631   True
# -----------------------------------------------------------------
# ['(0, 6]' '(120, 180]' '(14, 21]' '(180, 270]' '(21, 30]' '(270, 300]'
#  '(30, 45]' '(300, 365]' '(365, 765]' '(45, 60]' '(6, 7]' '(60, 90]'
#  '(7, 14]' '(90, 120]']

# %% [markdown]
# ## __Hypothesis Test 2 | Conclusions:__
# - Tukey analysis indicates that from __0-6 days__ lead time has no effect on cancellations; booking __7 days or more__ in advance contributes significantly to reservation cancellations.
# - Since p < a (0.05) we say that the null hypothesis is rejected and suggest an alternative: "that booking 7 days or more days in advance does have a statistical significant effect on the number of cancellations."
# - In the ANOVA test, the p-value of our categorical 'Lead Time Catg' variable is ~0.00 as shown in the above table. Since this value is less than our alpha of 0.05, we reject the null hypothesis.
# - In the Tukey test, post-hoc test, the interaction among variables (lead time for cancelled reservations and lead time categories) did show a statistically significant difference as shown in the following:
#     - "reject = False": Indicates Bookings made in advance - 0-6 days, __do not__ have an effect on cancellations.
#     - "reject = True" : Indicates Bookings made in advance - more than 7 days, __do__ have an effect on cancellations.

# %%
df_cancl['leadTime_catg'].unique()
# Out:
# array(['(60, 90]', '(21, 30]', '(45, 60]', '(30, 45]', '(0, 6]',
#        '(90, 120]', '(365, 765]', '(270, 300]', '(14, 21]', '(300, 365]',
#        '(7, 14]', '(120, 180]', '(6, 7]', '(180, 270]'], dtype=object)

# %%
# Cancellation Rate for 0-6 Days 
df_cancl_rate_6_days = (df_cancl[((df_cancl['leadTime_catg']=='(0, 6]') | (df_cancl['leadTime_catg']=='(6, 7]'))]['is_canceled'].sum() * 100)/df_cancl['is_canceled'].sum() 
df_cancl_rate_6_days   # 2.5513908710783944
# Out:
# 2.5513908710783944

# %%
# Cancellation Rate for more than 7 Days 
df_cancl_rate_7plus_days = (df_cancl[((df_cancl['leadTime_catg']!='(0, 6]') & (df_cancl['leadTime_catg']!='(6, 7]'))]['is_canceled'].sum() * 100)/df_cancl['is_canceled'].sum() 
df_cancl_rate_7plus_days  # 97.4486091289216
# Out:
# 97.4486091289216

# %% [markdown]
# # Final Conclusions

# %% [markdown]
# - Hypothesis testing is a strong and very important statistical tool that enable us to test conventional knowledge using sample data. Most parametric testing assume normality, but thanks to the central limit theorem, it is possible to bypass this assumption with large enough samples. Moreover, a variation of the two sample t-test called Welch’s t-test enables us to compare two sample means with unequal variances, which are the tests used to perform this study.

# %% [markdown]
# __Booking Cancellation Insights__
#
# - Lead time is a feature in the dataset that significantly contributes to canceled reservations.
# - Booking a reservation 7 days or more in advance increases the probability for a canceled reservation.
# - Cancellation Percentage: __0-6 days = 2.5 %__

# %% [markdown]
# # Future Work

# %% [markdown]
# - I would like to perform the following additional hypothesis tests:
#
#    - •	H1:  Cancellation probability is the highest for rooms booked online (OTA) and the lowest for rooms booked through travel agencies
#    -  •	H2: Country of origin affects the probability of cancellation
#    -  •	H3:  Guests travelling long  distances  are  less  likely  to  cancel  bookings  than  are domestic guests or guests from neighboring countries
#    - •	H4: Cancellation probability is higher during peak seasons
#        - NOTE: Summer Peak Season (June – August) The peak tourist season is from June until the end of August, and during this period there is a buzzing, vibrant atmosphere about the city.
#        In the off-season (roughly November–March), expect shorter hours, more lunchtime breaks at sights, and fewer activities — with the big exceptions of Christmas festivities and Entrudo (carnival), which is especially raucous in Lisbon and a few towns in the Algarve.
#    - •	H5:  Large groups of  adults  pose  a  higher  cancellation  risk  than  others,  but bookings that include children are less likely to be cancelled

# %%
end = datetime.datetime.now()
elapsed_time = end - start
print(f'Hypothesis Testing Total Execution Time: {elapsed_time}')
# Out:
# Hypothesis Testing Total Execution Time: 0:00:21.927622

# %% [markdown]
# # End Study
